# %% [markdown]
# # Libraries

# %%
import random
import numpy as np
import time
import matplotlib.pyplot as plt

# %% [markdown]
# # Constants, params

# %%
BOARD_SIZE = 16
POPULATION_SIZE = 1000
MUTATION_RATE = 0.1
MAX_GENERATION = 10000

# %% [markdown]
# # ChessBoard class (Visualize the Chessboard in 2D array)

# %%
class ChessBoard:
  """ A class to represent a chessboard in 2D array.

  Attributes:
    board_size (int): The size of the chessboard.
    board (numpy.ndarray): A 2D array representing the chessboard.

  Every cell of the initial chessboard will be filled by a dot "."
  And the Queen will be perform by a "Q" after process the `state`.

  """

  def __init__ (self, board_size:int):
    self.board_size = board_size
    self.board = np.full((self.board_size, self.board_size), ".", dtype='<U1')

  def place_queen(self, state):
    self.board.fill(".")
    for col, row in enumerate(state):
      if row >= 0 and row < self.board_size:
        self.board[row, col] = "Q"

  def print_board(self):
    print()
    for row in self.board:
      print(" ".join(row))

  def visualize_chessboard(self):
    plt.figure(figsize=(self.board_size, self.board_size))

    color_map = np.where(self.board == "Q", 1, 0)

    cmap = plt.cm.colors.ListedColormap(['lightblue', 'orange'])
    plt.imshow(color_map, cmap=cmap, interpolation='nearest')

    plt.xticks(ticks=np.arange(self.board_size), labels=np.arange(self.board_size))
    plt.yticks(ticks=np.arange(self.board_size), labels=np.arange(self.board_size))

    for row in range(self.board_size):
      for col in range(self.board_size):
        if self.board[row, col] == "Q":
            plt.text(col, row, 'Q', ha='center', va='center', fontsize=20, color='black', zorder=10)

    # Show main and anti diagonal grid
    # for start in range(self.board_size):
    #     plt.plot([start, self.board_size - 1], [0, self.board_size - 1 - start], color='blue', linewidth=1, zorder=5)
    #     plt.plot([start, 0], [self.board_size - 1, self.board_size - 1 - start], color='blue', linewidth=1, zorder=5)
    #     plt.plot([start, 0], [0, start], color='blue', linewidth=1, zorder=5)
    #     plt.plot([start, self.board_size - 1], [self.board_size - 1, start], color='blue', linewidth=1, zorder=5)

    queens_positions = [(row, col) for row in range(self.board_size) for col in range(self.board_size) if self.board[row, col] == "Q"]

    attacking_rows = set()
    attacking_cols = set()

    for i in range(len(queens_positions)):
      for j in range(i + 1, len(queens_positions)):
        row1, col1 = queens_positions[i]
        row2, col2 = queens_positions[j]

        if abs(row1 - row2) == abs(col1 - col2):
          if row1 < row2:
            plt.plot([col1, col2], [row1, row2], color='red', linewidth=4, zorder=5)
          else:
            plt.plot([col1, col2], [row1, row2], color='blue', linewidth=4, zorder=5)

        if row1 == row2:
          attacking_rows.add(row1)
        if col1 == col2:
          attacking_cols.add(col1)

    for row in attacking_rows:
      plt.axhline(y=row, color='red', linewidth=4, linestyle='--', zorder=4)

    for col in attacking_cols:
      plt.axvline(x=col, color='red', linewidth=4, linestyle='--', zorder=4)

    plt.title("Chessboard Visualization")
    plt.gca().invert_yaxis()
    plt.show()

if __name__ == "__main__":
    board_size = 8
    chessboard = ChessBoard(board_size)
    example_state = [0, 7, 4, 2, 5, 3, 1, 7]
    chessboard.place_queen(example_state)
    chessboard.visualize_chessboard()

# %% [markdown]
# # State class (Visualize the Chess board in 1D array)
#
# ## For example:
# - We have a 4x4 Chess board below (Index of colum and row both start from 0):
#     ```
#     3 . . . Q
#     2 Q . . .
#     1 . Q . .
#     0 . . Q .
#     \ 0 1 2 3
#     ```
# It will be visualized: `[2, 1, 0, 3]`
# - That means, `col[0]` have a Queen placed at `row[2]` -> `queen[0][2]` and so on ...

# %%
class State:
  """ A class to represent a state of a chessboard.

  Attributes:
    board_size (int): The size of the chessboard.
    state (list): A list of integers representing the row positions of queens.
    maximum_non_attacking_pairs (int): The maximum number of non-attacking pairs of queens.
    fitness_score (int): The fitness score of the state.
    selection_prob (float): The selection probability of the state.
    length (int): The length of the state
  """

  def __init__(self, board_size:int, random_state:bool):
    self.board_size = board_size
    self.state = []
    self.maximum_non_attacking_pairs = self.board_size * (self.board_size - 1) // 2
    self.selection_prob = None

    if random_state:
      self.state = [random.randint(0, self.board_size - 1) for _ in range(0, self.board_size)]
      self.fitness_score = self.calculate_fitness()
      self.length = self.get_state_length()

  def set_state(self, state):
    self.state = state
    self.fitness_score = self.calculate_fitness()
    self.length = self.get_state_length()

  def get_state(self):
    return self.state

  def set_selection_prob(self, selection_prob):
    self.selection_prob = selection_prob

  def get_selection_prob(self):
    return self.selection_prob

  def get_fitness(self):
    return self.fitness_score

  def calculate_fitness(self): # O(n)
    number_of_queen_in_each_column = [0] * (self.board_size)

    # For a chessboard size of N * N, there will be 2 * (2 * N - 1) diagonal from both side
    number_of_queen_in_main_diagonal = [0] * (2 * self.board_size - 1)  # From -(n - 1) to (n - 1)
    number_of_queen_in_anti_diagonal = [0] * (2 * self.board_size - 1)  # From 0 to (2n - 2)

    for row in range(self.board_size):
      col = self.state[row]
      number_of_queen_in_each_column[col] += 1
      number_of_queen_in_main_diagonal[row - col + (self.board_size - 1)] += 1
      number_of_queen_in_anti_diagonal[row + col] += 1

    attacking_pairs = 0

    for count in number_of_queen_in_each_column:
      if count > 1:
        attacking_pairs += count * (count - 1) // 2

    for count in number_of_queen_in_main_diagonal:
      if count > 1:
        attacking_pairs += count * (count - 1) // 2

    for count in number_of_queen_in_anti_diagonal:
      if count > 1:
        attacking_pairs += count

    return self.maximum_non_attacking_pairs - attacking_pairs

  def mutate_state(self, position: int, value: int):
    self.state[position - 1] = value
    self.fitness_score = self.calculate_fitness()

  def get_state_length(self):
    return __builtins__.len(self.state)

  def to_table(self, table_name:str):
    print(f"{table_name.upper()}")
    print(f"{'State':<65} {'Length':<15} {'Fitness Score':<15}")
    print("=" * 100)
    print(f"{str(self.get_state()):<67} {self.get_state_length(): <18} {self.get_fitness():<18}")

# %% [markdown]
# # Testing State class and ChessBoard class

# %%
if __name__ == "__main__":
  state_obj = State(board_size=BOARD_SIZE, random_state=False)
  state_obj.set_state([1, 4, 8, 14, 4, 10, 10, 6, 0, 0, 8, 8, 2, 15, 6, 1])
  state_obj.to_table("\nSolution")

  chess_board_obj = ChessBoard(board_size=16)
  chess_board_obj.place_queen(state_obj.get_state())
  # chess_board_obj.print_board()
  chess_board_obj.visualize_chessboard()
# Out:
# SOLUTION
# State                                                             Length          Fitness Score
# ====================================================================================================
# [1, 4, 8, 14, 4, 10, 10, 6, 0, 0, 8, 8, 2, 15, 6, 1]                16                 107

# %% [markdown]
# # GeneticAlgorithm class

# %%
class Population:
  def __init__(self, board_size:int, population_size:int, mutation_rate:float, none_population: bool):
    self.board_size = board_size
    self.population_size = population_size
    self.mutation_rate = mutation_rate
    if none_population:
      self.population = []
    else:
      self.population = self.generate_population()

    self.max_fitness = self.calculate_max_fitness()
    self.selection_prob = self.set_selection_prob_for_all_state()

  def add_new_state_to_population(self, state):
    self.population.append(state)

  def generate_population(self):
    return [State(self.board_size, random_state=True) for _ in range(self.population_size)]

  def print_population(self):
    for state in self.population:
      print(f"{str(state.get_state()):<70} {state.get_fitness():<18}")

  def get_population(self):
    return self.population

  def get_population_length(self):
    return __builtins__.len(self.population)

  def set_selection_prob_for_all_state(self):
    total_fitness = sum(state.get_fitness() for state in self.population)
    selection_probs = []
    for state in self.population:
      selection_prob = state.get_fitness() / total_fitness
      state.set_selection_prob(selection_prob)
      selection_probs.append(selection_prob)

    return selection_probs

  def evaluate_population(self):
    self.population.sort(key=lambda state: state.get_fitness(), reverse=True)
    self.population = self.population[:-1]

  def make_couples(self):
    if (len(self.population) % 2) != 0:
      self.population.append(self.population[0])

  def population_pop(self, pos:int):
    self.population.pop(pos)

  def crossover_two_state(self, parent1, parent2):
    crossover_start_point = random.randint(1, self.board_size - 3)
    crossover_end_point = random.randint(crossover_start_point + 1, self.board_size - 1)

    allele1 = parent1.get_state()[crossover_start_point:crossover_end_point]
    allele3 = parent2.get_state()[crossover_start_point:crossover_end_point]

    allele2 = parent2.get_state().copy()
    for num in allele1:
      for i in allele2:
        if num == i:
          allele2.remove(i)
          break

    allele2 = allele2

    allele4 = parent1.get_state().copy()
    for num in allele3:
      for i in allele4:
        if num == i:
          allele4.remove(i)
          break

    allele4 = allele4

    tmp1 = __builtins__.len(allele1) + __builtins__.len(allele2)
    tmp2 = __builtins__.len(allele3) + __builtins__.len(allele4)

    if tmp1 == 16:
      child1 = allele2[:crossover_start_point] + allele1 + allele2[crossover_start_point:]
    else:
      child_end_point = -(abs(BOARD_SIZE - tmp1))
      child1 = allele2[:crossover_start_point] + allele1 + allele2[crossover_start_point:child_end_point]

    if tmp2 == 16:
      child2 = allele4[:crossover_start_point] + allele3 + allele4[crossover_start_point:]
    else:
      child_end_point = -(abs(BOARD_SIZE - tmp2))
      child2 = allele4[:crossover_start_point] + allele3 + allele4[crossover_start_point:child_end_point]

    child1_state = State(self.board_size, random_state=False)
    child1_state.set_state(child1)

    child2_state = State(self.board_size, random_state=False)
    child2_state.set_state(child2)

    return child1_state, child2_state

  def crossover_population(self):
    for i in range(0, len(self.population), 2):
      parent1 = self.population[i]
      parent2 = self.population[i + 1]
      child1, child2 = self.crossover_two_state(parent1, parent2)

      self.population[i] = child1
      self.population[i + 1] = child2

  def mutation(self):
    for state in self.population:
        if random.random() < self.mutation_rate:
            random_position = random.randint(0, self.board_size - 1)
            random_value = random.randint(0, self.board_size - 1)
            state.mutate_state(random_position, random_value)

  def calculate_max_fitness(self):
    max_fitness = 0
    for state in self.population:
      if state.get_fitness() > max_fitness:
        max_fitness = state.get_fitness()
    return max_fitness

  def get_state_max_fitness(self):
    for state in self.population:
      if state.get_fitness() == self.max_fitness:
        return state

  def get_max_fitness(self):
    self.max_fitness = self.calculate_max_fitness()
    return self.max_fitness

  def to_table(self, table_name:str):
    print(f"{table_name.upper()} (Length = {self.get_population_length()})")
    print("=" * 103)
    print(f"{'State':<65} {'Fitness Score':<15} {'Selection Probability' :<15}")
    print("=" * 103)
    for state in self.population:
      print(f"{str(state.get_state()):<70} {state.get_fitness():<17} {state.get_selection_prob():.4f}")

if __name__ == "__main__":
  start_time = time.time()
  current_generation = Population(board_size=BOARD_SIZE, population_size=POPULATION_SIZE, mutation_rate=MUTATION_RATE, none_population=False)
  current_generation.to_table("\nInitial Population")

  loop = 0

  def run(current_generation):
    global loop

    while loop < MAX_GENERATION:
      print(f"LOOP: {loop} / {MAX_GENERATION} ", end="")
      current_generation.evaluate_population()
      current_generation.set_selection_prob_for_all_state()
      # current_generation.to_table("\nAfter evaluation")
      current_generation.make_couples()
      current_generation.set_selection_prob_for_all_state()
      # current_generation.to_table("\nAfter make couple")
      current_generation.crossover_population()
      current_generation.set_selection_prob_for_all_state()
      # current_generation.to_table("\nAfter crossover")
      current_generation.mutation()
      current_generation.set_selection_prob_for_all_state()
      # current_generation.to_table("\nAfter mutation")

      print(f"--> Max fitness: {current_generation.get_max_fitness()}")

      if current_generation.get_max_fitness() == 120:
        print(f"\n🟢🟢🟢 SOLUTION FOUND at loop {loop} / {MAX_GENERATION}")
        solution = State(board_size=BOARD_SIZE, random_state=False)
        solution = current_generation.get_state_max_fitness()
        solution.to_table("\n")

        chess_board_obj = ChessBoard(board_size=BOARD_SIZE)
        chess_board_obj.place_queen(solution.get_state())
        # chess_board_obj.print_board()
        chess_board_obj.visualize_chessboard()

        return
      loop += 1

    print("🔴🔴🔴 No solution found after {loop} loop")

  run(current_generation=current_generation)

  end_time = time.time()
  elapsed_time = end_time - start_time
  print(f"\nTime taken to find the solution: {elapsed_time:.2f} seconds")
# Out:
# INITIAL POPULATION (Length = 1000)
# =======================================================================================================
# State                                                             Fitness Score   Selection Probability
# =======================================================================================================
# [5, 11, 11, 0, 8, 7, 9, 5, 4, 10, 11, 12, 0, 11, 8, 9]                 97                0.0010
# [0, 13, 8, 3, 14, 5, 10, 8, 10, 12, 12, 8, 3, 3, 2, 9]                 99                0.0010
# [5, 5, 12, 7, 14, 6, 0, 6, 1, 5, 1, 5, 6, 1, 8, 13]                    91                0.0009
# [8, 2, 13, 1, 10, 9, 3, 11, 9, 6, 0, 6, 4, 3, 6, 2]                    100               0.0010
# [0, 1, 12, 6, 4, 2, 11, 8, 3, 3, 0, 3, 1, 0, 6, 15]                    101               0.0010
# [0, 4, 9, 0, 0, 5, 13, 7, 15, 1, 9, 6, 2, 2, 1, 14]                    99                0.0010
# [14, 11, 10, 11, 13, 13, 14, 9, 9, 11, 1, 10, 8, 13, 13, 13]           87                0.0009
# [2, 11, 14, 9, 11, 6, 6, 9, 9, 8, 11, 7, 15, 2, 10, 15]                96                0.0010
# [2, 12, 2, 1, 13, 11, 4, 4, 5, 6, 8, 2, 5, 9, 15, 14]                  100               0.0010
# [10, 3, 1, 7, 13, 1, 3, 1, 4, 4, 11, 3, 13, 10, 14, 2]                 104               0.0010
# [7, 4, 5, 13, 14, 5, 12, 10, 3, 5, 3, 6, 14, 2, 15, 2]                 102               0.0010
# [4, 1, 2, 15, 3, 5, 13, 15, 0, 7, 0, 8, 13, 7, 15, 3]                  101               0.0010
# [14, 0, 12, 13, 3, 14, 13, 9, 6, 1, 7, 1, 9, 10, 15, 10]               103               0.0010
# [4, 7, 10, 6, 12, 14, 15, 4, 8, 7, 6, 15, 1, 13, 10, 10]               102               0.0010
# [4, 10, 12, 15, 6, 7, 2, 15, 9, 4, 15, 0, 2, 15, 4, 7]                 97                0.0010
# [4, 2, 13, 3, 10, 11, 11, 3, 14, 13, 5, 4, 5, 2, 2, 5]                 95                0.0009
# [8, 13, 13, 14, 1, 14, 8, 4, 3, 5, 15, 8, 4, 15, 15, 2]                97                0.0010
# [2, 12, 1, 15, 6, 7, 12, 11, 12, 12, 5, 1, 10, 9, 2, 3]                99                0.0010
# [10, 4, 11, 15, 0, 4, 13, 11, 15, 3, 7, 13, 5, 9, 6, 7]                106               0.0011
# [4, 11, 11, 2, 0, 1, 10, 10, 4, 15, 3, 0, 9, 14, 12, 5]                106               0.0011
# [13, 9, 10, 13, 5, 3, 5, 4, 9, 7, 4, 6, 2, 3, 12, 5]                   96                0.0010
# [10, 8, 14, 10, 7, 12, 4, 9, 13, 12, 12, 0, 1, 3, 9, 2]                96                0.0010
# [2, 8, 11, 12, 12, 6, 1, 15, 9, 11, 6, 8, 15, 6, 3, 11]                100               0.0010
# [9, 5, 0, 8, 2, 12, 14, 13, 1, 4, 7, 4, 6, 2, 2, 0]                    102               0.0010
# [14, 0, 7, 10, 7, 13, 2, 9, 15, 0, 14, 2, 4, 0, 3, 7]                  102               0.0010
# [13, 3, 1, 15, 1, 12, 9, 3, 9, 0, 1, 4, 8, 1, 3, 8]                    101               0.0010
# [2, 11, 4, 11, 15, 3, 10, 0, 14, 11, 3, 14, 14, 14, 10, 15]            101               0.0010
# [2, 10, 14, 0, 8, 3, 0, 8, 9, 14, 8, 0, 15, 2, 11, 10]                 101               0.0010
# [13, 2, 6, 14, 10, 4, 15, 0, 10, 2, 3, 15, 14, 12, 10, 0]              103               0.0010
# [13, 14, 11, 10, 6, 15, 10, 7, 8, 14, 0, 14, 5, 3, 1, 8]               99                0.0010
# [7, 15, 10, 10, 9, 11, 15, 6, 0, 12, 15, 7, 5, 11, 6, 13]              102               0.0010
# [6, 15, 13, 9, 0, 13, 0, 11, 9, 7, 13, 3, 4, 13, 3, 13]                95                0.0009
# [0, 14, 7, 4, 2, 11, 1, 9, 6, 1, 3, 8, 3, 12, 5, 9]                    107               0.0011
# [9, 13, 5, 13, 11, 12, 3, 10, 7, 4, 15, 15, 5, 14, 13, 5]              101               0.0010
# [3, 8, 3, 0, 13, 5, 13, 11, 1, 7, 4, 12, 14, 2, 2, 8]                  105               0.0010
# [7, 8, 8, 1, 1, 15, 10, 2, 14, 7, 11, 2, 5, 2, 2, 13]                  101               0.0010
# [5, 14, 0, 10, 5, 2, 14, 11, 5, 13, 13, 3, 12, 12, 10, 12]             103               0.0010
# [6, 0, 8, 8, 5, 5, 8, 0, 1, 11, 4, 11, 13, 13, 1, 11]                  95                0.0009
# [4, 4, 5, 14, 15, 15, 2, 3, 2, 14, 15, 2, 6, 10, 5, 13]                99                0.0010
# [6, 1, 4, 8, 9, 4, 2, 10, 1, 1, 12, 10, 12, 11, 4, 13]                 101               0.0010
# [10, 13, 7, 8, 8, 8, 13, 1, 6, 13, 1, 9, 13, 4, 9, 11]                 101               0.0010
# [12, 11, 1, 10, 5, 9, 1, 7, 10, 10, 9, 3, 1, 15, 4, 6]                 99                0.0010
# [12, 4, 6, 11, 7, 6, 4, 4, 7, 7, 11, 6, 12, 14, 8, 3]                  101               0.0010
# [11, 12, 6, 11, 12, 11, 0, 8, 5, 7, 8, 9, 9, 0, 7, 8]                  95                0.0009
# [12, 14, 12, 3, 0, 12, 10, 4, 3, 2, 5, 8, 6, 14, 10, 9]                103               0.0010
# [5, 12, 5, 14, 4, 2, 9, 1, 1, 8, 10, 11, 7, 0, 13, 11]                 103               0.0010
# [10, 10, 10, 6, 8, 2, 12, 8, 3, 11, 6, 5, 14, 10, 8, 7]                99                0.0010
# [7, 2, 7, 9, 0, 14, 6, 2, 12, 14, 0, 14, 8, 5, 3, 3]                   103               0.0010
# [9, 6, 9, 7, 0, 1, 12, 15, 0, 12, 10, 0, 15, 11, 15, 12]               104               0.0010
# [13, 13, 15, 5, 15, 5, 12, 10, 3, 11, 5, 10, 13, 7, 14, 3]             101               0.0010
# [13, 9, 10, 8, 5, 7, 1, 0, 9, 10, 9, 1, 9, 15, 4, 3]                   97                0.0010
# [6, 5, 5, 1, 9, 6, 11, 6, 15, 5, 2, 0, 15, 11, 10, 7]                  99                0.0010
# [12, 0, 11, 7, 15, 14, 12, 1, 3, 4, 14, 1, 12, 15, 3, 4]               99                0.0010
# [6, 3, 4, 14, 8, 11, 10, 1, 12, 6, 12, 3, 10, 5, 12, 7]                96                0.0010
# [13, 12, 6, 6, 9, 3, 11, 14, 7, 11, 3, 15, 4, 15, 14, 0]               102               0.0010
# [5, 2, 14, 15, 12, 13, 6, 5, 3, 6, 3, 11, 7, 3, 12, 0]                 100               0.0010
# [15, 5, 1, 2, 8, 5, 5, 3, 3, 8, 6, 7, 0, 7, 13, 0]                     91                0.0009
# [6, 0, 14, 8, 0, 10, 6, 1, 4, 8, 2, 1, 0, 2, 1, 3]                     99                0.0010
# [11, 1, 10, 8, 13, 7, 3, 15, 9, 5, 14, 12, 9, 6, 2, 0]                 110               0.0011
# [3, 4, 11, 2, 0, 0, 15, 2, 14, 2, 4, 1, 7, 3, 14, 2]                   101               0.0010
# [2, 12, 6, 14, 14, 2, 13, 11, 14, 9, 10, 9, 3, 13, 9, 7]               100               0.0010
# [9, 5, 4, 2, 4, 2, 2, 1, 3, 1, 0, 3, 7, 15, 7, 0]                      102               0.0010
# [6, 2, 6, 14, 9, 9, 11, 11, 4, 5, 9, 4, 8, 6, 14, 0]                   95                0.0009
# [14, 9, 7, 10, 2, 9, 11, 15, 7, 12, 5, 10, 3, 8, 1, 8]                 103               0.0010
# [11, 14, 0, 3, 15, 2, 9, 5, 9, 12, 3, 4, 11, 7, 4, 4]                  105               0.0010
# [9, 13, 5, 7, 3, 6, 6, 4, 9, 12, 0, 12, 1, 14, 7, 12]                  96                0.0010
# [10, 13, 10, 6, 6, 11, 12, 3, 0, 9, 0, 11, 5, 0, 10, 5]                101               0.0010
# [4, 12, 3, 7, 4, 8, 4, 2, 5, 15, 13, 5, 5, 13, 13, 12]                 99                0.0010
# [15, 9, 4, 3, 15, 10, 10, 10, 5, 0, 6, 13, 8, 13, 5, 12]               101               0.0010
# [2, 6, 3, 0, 7, 14, 10, 5, 15, 5, 3, 12, 10, 3, 13, 7]                 106               0.0011
# [3, 6, 12, 6, 3, 10, 4, 6, 12, 1, 15, 9, 14, 15, 1, 6]                 95                0.0009
# [11, 1, 14, 15, 14, 15, 6, 8, 15, 5, 5, 10, 3, 3, 2, 0]                102               0.0010
# [0, 7, 1, 15, 9, 5, 8, 7, 14, 14, 15, 4, 11, 8, 2, 15]                 99                0.0010
# [13, 4, 8, 8, 3, 9, 5, 1, 13, 6, 10, 8, 10, 3, 13, 15]                 104               0.0010
# [3, 9, 5, 14, 5, 7, 13, 9, 14, 5, 9, 11, 6, 13, 4, 3]                  101               0.0010
# [8, 4, 1, 4, 8, 11, 11, 6, 7, 2, 13, 8, 10, 3, 10, 4]                  104               0.0010
# [5, 7, 5, 12, 4, 1, 7, 15, 3, 4, 13, 1, 9, 9, 5, 11]                   102               0.0010
# [8, 13, 3, 5, 3, 0, 12, 5, 14, 2, 2, 12, 2, 11, 0, 11]                 100               0.0010
# [15, 13, 13, 13, 13, 13, 5, 12, 4, 14, 15, 6, 2, 1, 4, 1]              92                0.0009
# [8, 10, 5, 1, 6, 10, 5, 1, 12, 2, 13, 9, 12, 6, 5, 4]                  100               0.0010
# [14, 9, 0, 6, 4, 7, 10, 0, 1, 8, 2, 9, 1, 2, 14, 10]                   106               0.0011
# [1, 1, 9, 13, 0, 3, 6, 13, 11, 14, 5, 2, 3, 6, 1, 7]                   107               0.0011
# [0, 1, 7, 12, 6, 6, 4, 8, 14, 13, 0, 14, 4, 14, 5, 4]                  99                0.0010
# [0, 7, 3, 13, 8, 5, 10, 9, 0, 8, 5, 4, 8, 1, 0, 6]                     102               0.0010
# [3, 5, 9, 1, 13, 1, 3, 4, 14, 1, 7, 3, 15, 13, 15, 7]                  96                0.0010
# [13, 10, 8, 0, 6, 2, 10, 9, 7, 3, 0, 15, 8, 6, 4, 9]                   105               0.0010
# [3, 5, 8, 6, 6, 8, 5, 15, 10, 2, 1, 5, 14, 0, 8, 1]                    94                0.0009
# [2, 11, 3, 12, 12, 8, 0, 2, 12, 14, 3, 15, 10, 3, 2, 8]                101               0.0010
# [5, 4, 1, 1, 3, 9, 0, 2, 2, 1, 11, 12, 6, 11, 7, 12]                   102               0.0010
# [3, 2, 3, 15, 5, 8, 5, 11, 7, 4, 15, 0, 5, 4, 7, 4]                    94                0.0009
# [2, 3, 2, 7, 3, 8, 13, 0, 10, 5, 14, 11, 9, 0, 14, 11]                 101               0.0010
# [2, 15, 11, 5, 3, 0, 5, 6, 12, 8, 7, 1, 13, 0, 1, 13]                  103               0.0010
# [8, 10, 7, 4, 13, 2, 8, 11, 6, 0, 11, 10, 14, 0, 15, 4]                102               0.0010
# [4, 15, 11, 12, 2, 12, 3, 9, 7, 1, 6, 4, 7, 5, 2, 7]                   103               0.0010
# [7, 4, 12, 10, 15, 3, 1, 8, 8, 8, 0, 1, 15, 15, 2, 5]                  104               0.0010
# [0, 6, 6, 14, 0, 4, 15, 3, 10, 15, 12, 9, 8, 0, 5, 2]                  106               0.0011
# [3, 3, 15, 2, 2, 5, 15, 2, 4, 2, 1, 15, 4, 1, 15, 11]                  100               0.0010
# [4, 14, 1, 7, 12, 9, 0, 13, 12, 2, 2, 5, 3, 7, 11, 11]                 100               0.0010
# [1, 8, 1, 13, 15, 5, 13, 7, 12, 11, 12, 3, 10, 7, 13, 11]              100               0.0010
# [15, 13, 3, 1, 6, 6, 12, 0, 5, 11, 13, 8, 2, 6, 13, 2]                 105               0.0010
# [4, 13, 0, 11, 3, 5, 3, 3, 4, 8, 2, 1, 4, 14, 5, 0]                    102               0.0010
# [0, 6, 8, 3, 3, 14, 3, 10, 0, 15, 6, 3, 4, 1, 7, 15]                   98                0.0010
# [0, 8, 13, 0, 14, 11, 13, 8, 7, 9, 12, 4, 11, 8, 13, 13]               98                0.0010
# [10, 13, 13, 7, 4, 7, 12, 10, 9, 2, 1, 4, 0, 1, 3, 0]                  98                0.0010
# [13, 11, 4, 5, 15, 2, 14, 6, 0, 10, 14, 13, 14, 13, 11, 8]             96                0.0010
# [13, 12, 14, 6, 8, 4, 4, 3, 6, 1, 0, 3, 1, 13, 2, 6]                   98                0.0010
# [15, 5, 11, 10, 2, 0, 8, 13, 5, 7, 15, 8, 11, 4, 3, 15]                105               0.0010
# [15, 2, 6, 2, 13, 3, 10, 3, 2, 4, 2, 14, 4, 10, 4, 13]                 99                0.0010
# [10, 13, 3, 15, 7, 8, 5, 1, 0, 12, 13, 8, 0, 12, 5, 13]                99                0.0010
# [1, 13, 5, 7, 4, 14, 14, 0, 8, 5, 14, 11, 4, 8, 2, 8]                  100               0.0010
# [14, 6, 2, 6, 12, 11, 4, 7, 6, 0, 15, 2, 9, 13, 12, 15]                94                0.0009
# [0, 9, 3, 7, 9, 9, 1, 15, 8, 0, 11, 10, 10, 8, 7, 1]                   97                0.0010
# [12, 0, 5, 2, 0, 1, 13, 15, 3, 10, 11, 5, 13, 3, 4, 8]                 106               0.0011
# [10, 9, 14, 0, 7, 7, 6, 1, 15, 10, 15, 3, 5, 9, 8, 1]                  106               0.0011
# [1, 3, 3, 11, 1, 8, 4, 3, 5, 6, 5, 8, 6, 9, 4, 14]                     94                0.0009
# [6, 4, 4, 14, 9, 1, 0, 2, 9, 1, 14, 6, 6, 9, 7, 0]                     100               0.0010
# [2, 13, 7, 15, 3, 7, 9, 3, 1, 2, 9, 5, 8, 9, 3, 2]                     99                0.0010
# [12, 9, 2, 9, 5, 10, 14, 3, 3, 10, 6, 2, 13, 7, 3, 3]                  100               0.0010
# [12, 14, 9, 1, 2, 1, 0, 1, 0, 14, 14, 14, 3, 6, 11, 9]                 94                0.0009
# [4, 5, 9, 1, 0, 8, 14, 14, 4, 3, 6, 7, 5, 11, 4, 0]                    98                0.0010
# [15, 3, 6, 1, 2, 3, 11, 0, 12, 13, 3, 3, 15, 5, 5, 0]                  97                0.0010
# [4, 11, 2, 2, 14, 8, 14, 13, 14, 15, 4, 8, 1, 1, 8, 7]                 95                0.0009
# [13, 12, 4, 4, 4, 9, 9, 14, 8, 9, 5, 12, 13, 3, 10, 8]                 97                0.0010
# [10, 3, 15, 1, 2, 4, 13, 12, 10, 1, 7, 0, 9, 9, 9, 8]                  102               0.0010
# [4, 14, 6, 12, 15, 13, 14, 3, 14, 9, 4, 1, 4, 11, 10, 0]               104               0.0010
# [1, 8, 13, 0, 12, 0, 5, 4, 13, 12, 3, 11, 9, 5, 0, 15]                 105               0.0010
# [3, 6, 1, 4, 5, 2, 8, 10, 2, 3, 9, 9, 11, 12, 15, 4]                   98                0.0010
# [8, 4, 4, 11, 13, 1, 0, 5, 9, 6, 9, 14, 5, 5, 13, 4]                   101               0.0010
# [9, 4, 1, 6, 11, 5, 14, 9, 15, 3, 15, 6, 7, 10, 6, 4]                  103               0.0010
# [14, 8, 10, 2, 6, 9, 1, 11, 4, 3, 11, 13, 11, 14, 6, 6]                102               0.0010
# [13, 7, 2, 2, 9, 0, 5, 12, 6, 1, 11, 6, 8, 8, 12, 7]                   102               0.0010
# [11, 15, 12, 2, 1, 12, 4, 0, 14, 13, 0, 4, 3, 8, 5, 4]                 103               0.0010
# [14, 14, 6, 13, 0, 7, 15, 15, 13, 9, 14, 11, 4, 4, 12, 1]              105               0.0010
# [3, 8, 8, 8, 14, 10, 14, 11, 13, 2, 11, 15, 13, 15, 1, 14]             98                0.0010
# [6, 11, 8, 7, 2, 14, 7, 9, 9, 5, 1, 4, 7, 6, 9, 10]                    100               0.0010
# [11, 12, 2, 1, 1, 12, 13, 8, 14, 3, 0, 8, 7, 13, 2, 12]                102               0.0010
# [9, 2, 10, 4, 0, 14, 2, 0, 2, 14, 9, 3, 4, 13, 10, 0]                  100               0.0010
# [1, 7, 7, 15, 4, 14, 9, 12, 2, 2, 7, 12, 3, 14, 2, 12]                 97                0.0010
# [13, 3, 1, 7, 0, 4, 9, 6, 6, 13, 0, 1, 12, 6, 5, 1]                    99                0.0010
# [1, 10, 6, 3, 7, 0, 0, 10, 10, 4, 11, 0, 3, 8, 2, 15]                  100               0.0010
# [15, 13, 6, 14, 8, 0, 9, 3, 11, 9, 3, 5, 6, 12, 6, 8]                  106               0.0011
# [4, 3, 13, 6, 11, 5, 14, 0, 2, 11, 3, 1, 7, 9, 12, 9]                  106               0.0011
# [15, 1, 0, 15, 9, 6, 1, 9, 6, 9, 3, 0, 15, 3, 12, 9]                   93                0.0009
# [5, 5, 8, 11, 7, 1, 2, 5, 8, 3, 3, 2, 13, 2, 2, 0]                     98                0.0010
# [3, 9, 15, 8, 8, 2, 10, 12, 2, 2, 7, 6, 2, 15, 14, 7]                  99                0.0010
# [2, 8, 10, 15, 9, 14, 6, 11, 7, 1, 14, 8, 14, 7, 3, 8]                 105               0.0010
# [9, 7, 5, 8, 9, 14, 5, 7, 3, 10, 15, 7, 8, 14, 4, 15]                  98                0.0010
# [14, 6, 2, 15, 0, 11, 6, 8, 6, 7, 3, 15, 9, 13, 0, 7]                  101               0.0010
# [0, 2, 9, 3, 1, 12, 6, 14, 10, 2, 7, 10, 13, 4, 9, 8]                  99                0.0010
# [13, 5, 7, 8, 12, 7, 3, 2, 5, 2, 3, 8, 12, 15, 7, 14]                  96                0.0010
# [6, 9, 14, 5, 5, 10, 14, 15, 6, 14, 12, 3, 9, 0, 7, 9]                 101               0.0010
# [8, 0, 6, 5, 8, 9, 8, 1, 0, 10, 7, 15, 14, 10, 12, 8]                  90                0.0009
# [7, 4, 4, 9, 15, 1, 5, 4, 8, 13, 4, 15, 10, 6, 15, 3]                  102               0.0010
# [14, 6, 0, 6, 5, 8, 3, 0, 10, 10, 4, 12, 0, 6, 14, 4]                  96                0.0010
# [13, 11, 5, 3, 3, 0, 14, 14, 7, 9, 12, 1, 10, 15, 10, 11]              106               0.0011
# [1, 13, 11, 7, 1, 0, 14, 5, 2, 7, 1, 3, 14, 10, 0, 2]                  104               0.0010
# [9, 15, 15, 6, 10, 14, 0, 2, 1, 15, 7, 3, 6, 1, 0, 7]                  99                0.0010
# [8, 15, 3, 12, 5, 15, 2, 7, 14, 5, 7, 13, 15, 9, 0, 1]                 101               0.0010
# [6, 4, 13, 9, 1, 14, 3, 9, 14, 3, 10, 10, 11, 12, 11, 4]               97                0.0010
# [12, 12, 14, 14, 12, 4, 10, 13, 8, 2, 4, 0, 12, 9, 13, 7]              99                0.0010
# [13, 14, 7, 3, 15, 14, 15, 14, 6, 12, 8, 14, 0, 10, 4, 1]              102               0.0010
# [2, 6, 12, 14, 1, 5, 3, 4, 3, 9, 3, 9, 12, 10, 6, 4]                   100               0.0010
# [6, 7, 4, 7, 10, 13, 11, 10, 14, 10, 3, 8, 10, 12, 7, 9]               96                0.0010
# [10, 2, 5, 14, 10, 3, 15, 12, 11, 8, 8, 11, 8, 11, 0, 6]               101               0.0010
# [6, 14, 15, 5, 7, 0, 0, 7, 8, 5, 3, 1, 15, 9, 11, 0]                   104               0.0010
# [5, 12, 11, 12, 3, 13, 11, 7, 10, 7, 8, 8, 5, 6, 15, 2]                101               0.0010
# [3, 10, 4, 0, 9, 2, 4, 3, 4, 6, 1, 6, 3, 4, 11, 7]                     90                0.0009
# [7, 12, 12, 4, 6, 13, 14, 15, 2, 2, 3, 0, 5, 9, 15, 13]                99                0.0010
# [9, 5, 0, 0, 7, 5, 2, 15, 11, 10, 15, 15, 7, 4, 1, 5]                  107               0.0011
# [11, 5, 4, 11, 2, 12, 6, 14, 9, 11, 5, 2, 8, 13, 1, 5]                 100               0.0010
# [6, 6, 11, 10, 8, 3, 12, 11, 3, 10, 5, 4, 8, 10, 0, 0]                 102               0.0010
# [5, 10, 14, 0, 6, 9, 6, 10, 3, 12, 6, 2, 13, 11, 14, 8]                109               0.0011
# [2, 11, 6, 3, 14, 12, 2, 3, 0, 7, 4, 15, 14, 15, 3, 7]                 99                0.0010
# [3, 2, 2, 0, 8, 8, 6, 4, 7, 14, 8, 0, 7, 1, 4, 9]                      101               0.0010
# [12, 7, 10, 1, 13, 14, 9, 11, 13, 15, 9, 1, 8, 13, 14, 11]             102               0.0010
# [5, 7, 9, 10, 0, 14, 13, 5, 1, 13, 2, 13, 11, 15, 1, 10]               106               0.0011
# [2, 14, 15, 6, 14, 4, 1, 1, 12, 6, 13, 5, 9, 15, 0, 2]                 104               0.0010
# [0, 11, 11, 12, 11, 8, 4, 13, 9, 8, 12, 6, 6, 12, 3, 9]                100               0.0010
# [12, 14, 3, 0, 5, 5, 10, 5, 7, 14, 11, 9, 6, 0, 11, 15]                104               0.0010
# [0, 12, 5, 9, 14, 9, 1, 15, 0, 4, 14, 14, 2, 8, 14, 4]                 99                0.0010
# [2, 2, 15, 7, 0, 10, 2, 10, 12, 10, 4, 3, 1, 2, 3, 5]                  95                0.0009
# [12, 6, 4, 8, 6, 6, 15, 4, 3, 8, 5, 5, 7, 8, 7, 1]                     94                0.0009
# [11, 8, 2, 13, 11, 4, 11, 4, 6, 0, 7, 11, 2, 0, 11, 15]                91                0.0009
# [5, 2, 10, 8, 5, 2, 4, 4, 14, 1, 1, 4, 10, 12, 4, 4]                   95                0.0009
# [11, 6, 4, 9, 2, 15, 1, 0, 13, 12, 9, 4, 6, 15, 3, 7]                  106               0.0011
# [13, 3, 12, 8, 14, 6, 1, 5, 4, 15, 6, 0, 14, 7, 3, 3]                  104               0.0010
# [14, 1, 13, 7, 11, 4, 4, 12, 10, 8, 0, 3, 15, 7, 10, 6]                109               0.0011
# [10, 6, 9, 0, 11, 8, 4, 4, 3, 4, 14, 0, 10, 15, 13, 8]                 102               0.0010
# [6, 11, 14, 5, 9, 4, 9, 2, 6, 3, 11, 1, 2, 6, 4, 9]                    100               0.0010
# [2, 11, 15, 9, 12, 15, 15, 4, 11, 12, 7, 12, 6, 5, 13, 12]             95                0.0009
# [1, 11, 10, 8, 4, 3, 15, 1, 4, 1, 4, 5, 4, 1, 1, 6]                    88                0.0009
# [15, 10, 1, 7, 7, 13, 3, 9, 4, 11, 12, 9, 4, 14, 13, 10]               103               0.0010
# [8, 5, 1, 10, 7, 5, 12, 9, 3, 14, 3, 0, 0, 0, 8, 0]                    105               0.0010
# [14, 0, 4, 14, 14, 1, 4, 13, 5, 7, 13, 7, 9, 15, 8, 14]                102               0.0010
# [9, 2, 15, 11, 10, 0, 10, 3, 8, 4, 0, 5, 15, 7, 1, 8]                  107               0.0011
# [0, 0, 13, 13, 14, 10, 2, 15, 0, 9, 7, 7, 0, 13, 0, 7]                 89                0.0009
# [11, 10, 7, 2, 5, 14, 12, 15, 13, 1, 8, 10, 6, 8, 0, 9]                104               0.0010
# [8, 6, 11, 10, 11, 6, 12, 5, 11, 1, 1, 3, 5, 5, 6, 4]                  95                0.0009
# [0, 5, 12, 8, 1, 10, 3, 10, 14, 6, 7, 15, 14, 1, 2, 6]                 99                0.0010
# [6, 9, 9, 6, 5, 12, 13, 5, 13, 1, 11, 13, 15, 10, 0, 0]                102               0.0010
# [10, 2, 15, 2, 9, 2, 7, 0, 5, 15, 6, 10, 10, 1, 1, 13]                 103               0.0010
# [7, 1, 10, 12, 5, 10, 11, 13, 3, 2, 7, 14, 0, 11, 1, 15]               105               0.0010
# [13, 7, 5, 6, 6, 2, 7, 3, 2, 7, 7, 0, 8, 11, 10, 10]                   96                0.0010
# [5, 3, 6, 0, 10, 10, 11, 6, 13, 14, 4, 7, 6, 2, 7, 7]                  94                0.0009
# [13, 5, 14, 1, 8, 4, 0, 0, 5, 1, 3, 15, 8, 14, 9, 13]                  104               0.0010
# [6, 11, 11, 8, 7, 5, 0, 11, 12, 1, 9, 10, 1, 0, 14, 11]                100               0.0010
# [1, 2, 3, 14, 1, 1, 15, 4, 14, 2, 11, 13, 8, 11, 1, 15]                94                0.0009
# [15, 13, 7, 4, 12, 12, 7, 4, 4, 4, 5, 0, 5, 3, 11, 6]                  98                0.0010
# [9, 11, 8, 4, 13, 6, 4, 12, 4, 5, 4, 5, 2, 9, 8, 11]                   90                0.0009
# [3, 6, 2, 15, 13, 5, 3, 13, 6, 9, 4, 14, 7, 0, 9, 13]                  104               0.0010
# [5, 12, 14, 12, 7, 4, 6, 6, 1, 15, 13, 7, 12, 7, 7, 8]                 96                0.0010
# [5, 10, 11, 7, 13, 14, 8, 7, 9, 4, 3, 4, 10, 0, 10, 1]                 100               0.0010
# [2, 10, 5, 8, 9, 11, 10, 6, 10, 10, 9, 13, 4, 9, 13, 9]                89                0.0009
# [5, 14, 12, 5, 12, 0, 13, 13, 0, 4, 2, 13, 4, 4, 9, 15]                98                0.0010
# [4, 5, 2, 3, 11, 2, 2, 0, 14, 15, 5, 15, 13, 12, 3, 10]                97                0.0010
# [8, 3, 7, 7, 4, 7, 0, 10, 13, 7, 0, 8, 4, 6, 0, 7]                     94                0.0009
# [8, 3, 4, 7, 6, 6, 6, 2, 0, 4, 7, 11, 6, 7, 1, 6]                      96                0.0010
# [15, 2, 2, 8, 2, 12, 12, 3, 7, 7, 12, 4, 0, 6, 14, 13]                 103               0.0010
# [14, 13, 5, 10, 12, 14, 1, 15, 6, 9, 13, 10, 9, 2, 9, 15]              100               0.0010
# [7, 5, 8, 9, 11, 7, 11, 5, 2, 5, 7, 3, 7, 4, 2, 3]                     95                0.0009
# [15, 1, 2, 15, 15, 8, 7, 5, 1, 3, 10, 5, 13, 11, 13, 3]                101               0.0010
# [12, 8, 15, 5, 2, 9, 7, 13, 8, 9, 13, 9, 14, 13, 9, 11]                98                0.0010
# [8, 13, 14, 5, 9, 14, 3, 0, 14, 4, 7, 3, 10, 2, 14, 2]                 100               0.0010
# [1, 3, 15, 9, 8, 6, 15, 15, 5, 10, 11, 10, 0, 15, 3, 8]                96                0.0010
# [12, 3, 11, 8, 2, 9, 5, 0, 8, 12, 2, 7, 15, 10, 15, 9]                 110               0.0011
# [3, 3, 15, 5, 7, 7, 10, 15, 2, 5, 6, 11, 5, 4, 8, 4]                   99                0.0010
# [13, 2, 11, 2, 10, 5, 15, 11, 5, 0, 8, 0, 14, 1, 9, 7]                 108               0.0011
# [4, 11, 13, 2, 8, 5, 14, 8, 10, 3, 12, 1, 6, 13, 1, 3]                 102               0.0010
# [10, 9, 11, 12, 0, 3, 14, 14, 10, 4, 1, 6, 7, 11, 9, 12]               102               0.0010
# [0, 9, 14, 13, 6, 13, 9, 2, 15, 11, 13, 1, 14, 4, 6, 0]                98                0.0010
# [9, 8, 11, 9, 10, 3, 7, 13, 0, 6, 8, 6, 6, 14, 10, 2]                  98                0.0010
# [3, 5, 8, 0, 9, 7, 7, 3, 11, 1, 11, 5, 3, 14, 1, 4]                    98                0.0010
# [3, 15, 10, 14, 6, 10, 5, 13, 6, 1, 12, 6, 2, 7, 3, 14]                103               0.0010
# [4, 11, 0, 0, 5, 0, 4, 3, 9, 3, 0, 6, 9, 0, 8, 7]                      93                0.0009
# [4, 0, 8, 13, 15, 5, 9, 9, 2, 4, 11, 7, 15, 11, 14, 3]                 107               0.0011
# [2, 9, 6, 15, 2, 8, 12, 7, 2, 0, 8, 2, 8, 15, 12, 5]                   95                0.0009
# [1, 8, 0, 12, 0, 4, 13, 2, 2, 15, 15, 7, 12, 5, 3, 4]                  103               0.0010
# [11, 6, 2, 11, 12, 10, 3, 9, 14, 5, 1, 14, 10, 9, 3, 13]               102               0.0010
# [4, 8, 15, 13, 14, 5, 3, 1, 2, 1, 2, 0, 15, 12, 14, 9]                 105               0.0010
# [6, 14, 12, 8, 10, 9, 8, 6, 6, 11, 10, 2, 6, 6, 3, 5]                  96                0.0010
# [14, 0, 1, 8, 14, 8, 9, 9, 4, 2, 12, 2, 12, 0, 6, 12]                  104               0.0010
# [4, 1, 1, 14, 10, 4, 11, 4, 0, 14, 5, 10, 14, 9, 8, 2]                 103               0.0010
# [9, 12, 9, 2, 15, 13, 4, 3, 5, 5, 9, 1, 15, 12, 0, 3]                  98                0.0010
# [3, 3, 7, 1, 15, 10, 5, 13, 7, 9, 12, 3, 5, 13, 0, 6]                  104               0.0010
# [1, 5, 13, 7, 13, 5, 13, 15, 12, 10, 14, 4, 1, 15, 15, 11]             97                0.0010
# [14, 11, 4, 5, 1, 15, 13, 9, 5, 2, 3, 12, 7, 5, 8, 7]                  103               0.0010
# [11, 13, 12, 8, 0, 15, 14, 4, 12, 6, 2, 5, 10, 8, 13, 1]               105               0.0010
# [3, 5, 15, 6, 6, 10, 4, 11, 11, 14, 14, 2, 6, 7, 3, 5]                 97                0.0010
# [7, 2, 12, 12, 14, 10, 0, 3, 11, 1, 8, 1, 1, 15, 11, 8]                107               0.0011
# [14, 10, 8, 12, 15, 0, 12, 5, 13, 15, 11, 4, 9, 14, 10, 4]             101               0.0010
# [9, 13, 10, 6, 10, 0, 9, 3, 13, 11, 14, 9, 0, 10, 2, 3]                99                0.0010
# [0, 6, 5, 5, 1, 8, 4, 6, 14, 14, 5, 5, 8, 13, 10, 7]                   101               0.0010
# [2, 6, 13, 8, 4, 12, 15, 6, 5, 10, 3, 6, 6, 7, 7, 0]                   101               0.0010
# [11, 2, 11, 11, 13, 7, 3, 7, 0, 3, 15, 4, 8, 14, 0, 7]                 104               0.0010
# [2, 11, 11, 9, 8, 4, 9, 7, 1, 12, 14, 8, 13, 15, 12, 15]               106               0.0011
# [9, 5, 6, 15, 12, 1, 5, 12, 14, 9, 3, 6, 6, 6, 5, 8]                   97                0.0010
# [14, 8, 10, 7, 7, 6, 3, 7, 7, 8, 10, 8, 7, 6, 9, 11]                   92                0.0009
# [11, 7, 15, 4, 10, 10, 15, 2, 0, 7, 12, 8, 10, 8, 5, 2]                100               0.0010
# [4, 15, 2, 15, 11, 7, 11, 4, 11, 15, 6, 8, 12, 15, 2, 12]              94                0.0009
# [13, 6, 5, 0, 2, 0, 15, 5, 9, 2, 3, 11, 7, 11, 8, 11]                  103               0.0010
# [10, 1, 7, 7, 1, 13, 13, 6, 3, 11, 8, 14, 5, 9, 3, 11]                 108               0.0011
# [10, 4, 6, 4, 7, 6, 1, 0, 4, 13, 14, 5, 1, 8, 14, 14]                  101               0.0010
# [3, 8, 14, 3, 4, 5, 6, 10, 14, 0, 12, 14, 5, 2, 5, 11]                 97                0.0010
# [9, 8, 3, 12, 6, 8, 10, 9, 12, 2, 12, 0, 1, 4, 6, 10]                  97                0.0010
# [10, 9, 0, 9, 12, 4, 9, 6, 6, 10, 6, 7, 3, 11, 2, 5]                   100               0.0010
# [2, 8, 5, 2, 9, 13, 9, 12, 9, 1, 6, 8, 13, 15, 12, 0]                  105               0.0010
# [2, 9, 4, 2, 15, 6, 13, 10, 2, 4, 3, 13, 9, 11, 15, 12]                100               0.0010
# [8, 5, 7, 4, 8, 5, 2, 6, 4, 9, 13, 13, 7, 2, 10, 13]                   101               0.0010
# [3, 13, 4, 10, 4, 4, 10, 11, 2, 15, 10, 0, 13, 11, 13, 9]              103               0.0010
# [10, 3, 7, 2, 0, 13, 11, 9, 6, 4, 0, 0, 9, 7, 12, 4]                   106               0.0011
# [4, 14, 1, 8, 4, 1, 11, 2, 8, 4, 13, 12, 5, 2, 9, 7]                   102               0.0010
# [4, 12, 6, 0, 2, 0, 1, 6, 15, 5, 9, 10, 3, 0, 7, 12]                   104               0.0010
# [13, 3, 5, 7, 5, 6, 8, 15, 1, 4, 4, 12, 1, 3, 1, 3]                    101               0.0010
# [2, 4, 4, 13, 2, 15, 13, 0, 11, 3, 8, 3, 1, 11, 6, 4]                  98                0.0010
# [10, 14, 3, 11, 9, 15, 5, 6, 13, 11, 11, 6, 4, 15, 7, 6]               100               0.0010
# [7, 5, 1, 0, 7, 4, 0, 14, 15, 8, 12, 4, 1, 0, 5, 13]                   101               0.0010
# [3, 1, 6, 2, 8, 10, 4, 6, 15, 4, 1, 8, 3, 5, 4, 1]                     102               0.0010
# [12, 15, 9, 5, 5, 11, 6, 0, 4, 6, 6, 1, 0, 2, 6, 13]                   101               0.0010
# [4, 3, 10, 1, 8, 0, 8, 13, 10, 1, 7, 13, 9, 0, 12, 10]                 98                0.0010
# [14, 7, 9, 12, 3, 7, 11, 0, 3, 1, 5, 15, 11, 8, 3, 8]                  99                0.0010
# [11, 4, 12, 7, 7, 1, 11, 3, 2, 8, 9, 5, 11, 9, 1, 5]                   98                0.0010
# [5, 11, 6, 4, 0, 3, 10, 13, 9, 3, 9, 3, 12, 1, 11, 12]                 105               0.0010
# [9, 4, 14, 12, 10, 15, 12, 12, 8, 7, 10, 7, 6, 2, 9, 6]                100               0.0010
# [3, 8, 10, 12, 2, 15, 0, 2, 7, 6, 15, 0, 13, 11, 14, 13]               102               0.0010
# [9, 4, 12, 6, 9, 14, 13, 2, 15, 4, 11, 0, 9, 7, 12, 13]                100               0.0010
# [6, 5, 4, 7, 14, 9, 3, 8, 5, 2, 14, 12, 1, 11, 6, 15]                  102               0.0010
# [6, 10, 4, 9, 9, 2, 4, 1, 9, 10, 13, 4, 1, 11, 15, 0]                  101               0.0010
# [7, 4, 8, 15, 14, 13, 10, 15, 10, 9, 12, 10, 10, 5, 11, 0]             102               0.0010
# [13, 3, 10, 5, 14, 2, 4, 6, 3, 9, 14, 10, 14, 4, 12, 15]               102               0.0010
# [3, 5, 14, 7, 8, 4, 0, 10, 4, 9, 1, 10, 3, 15, 12, 3]                  103               0.0010
# [15, 11, 12, 6, 1, 9, 7, 2, 3, 6, 6, 10, 7, 9, 1, 1]                   97                0.0010
# [4, 10, 15, 13, 6, 3, 3, 15, 9, 8, 9, 13, 4, 13, 3, 6]                 102               0.0010
# [5, 11, 11, 14, 14, 6, 6, 5, 12, 10, 9, 6, 2, 9, 5, 5]                 95                0.0009
# [4, 11, 1, 4, 11, 9, 5, 13, 4, 5, 3, 7, 6, 14, 15, 1]                  100               0.0010
# [8, 10, 13, 13, 15, 2, 2, 8, 5, 15, 14, 3, 6, 9, 15, 5]                103               0.0010
# [3, 9, 6, 12, 14, 10, 2, 14, 4, 14, 4, 3, 3, 15, 2, 8]                 101               0.0010
# [2, 5, 15, 11, 15, 8, 7, 14, 5, 9, 10, 10, 7, 10, 8, 10]               100               0.0010
# [8, 12, 7, 15, 6, 4, 15, 12, 13, 10, 13, 12, 10, 7, 2, 1]              99                0.0010
# [13, 13, 4, 0, 6, 10, 1, 11, 11, 5, 7, 6, 0, 5, 3, 14]                 105               0.0010
# [14, 1, 11, 1, 10, 6, 7, 9, 13, 8, 3, 7, 6, 15, 11, 5]                 107               0.0011
# [2, 12, 4, 10, 3, 5, 8, 5, 3, 13, 10, 14, 11, 4, 13, 15]               104               0.0010
# [15, 3, 7, 14, 6, 13, 15, 4, 6, 0, 7, 2, 9, 5, 9, 10]                  102               0.0010
# [10, 11, 6, 0, 0, 1, 4, 8, 9, 0, 12, 15, 5, 6, 10, 2]                  103               0.0010
# [10, 13, 10, 7, 5, 12, 0, 14, 9, 2, 1, 2, 13, 1, 15, 5]                99                0.0010
# [14, 9, 10, 6, 0, 11, 2, 8, 9, 8, 7, 9, 10, 13, 15, 15]                104               0.0010
# [6, 11, 8, 1, 11, 10, 12, 11, 0, 5, 13, 3, 10, 10, 3, 1]               99                0.0010
# [10, 15, 14, 10, 14, 15, 9, 10, 9, 2, 5, 6, 3, 14, 11, 12]             95                0.0009
# [12, 6, 0, 13, 1, 5, 0, 1, 4, 10, 2, 15, 13, 7, 4, 15]                 107               0.0011
# [0, 6, 15, 15, 5, 2, 2, 15, 5, 8, 1, 6, 11, 13, 3, 0]                  104               0.0010
# [9, 7, 1, 3, 13, 14, 7, 5, 11, 10, 11, 13, 11, 5, 4, 0]                102               0.0010
# [8, 8, 15, 6, 9, 7, 10, 9, 15, 0, 12, 10, 8, 3, 5, 2]                  101               0.0010
# [8, 14, 6, 7, 2, 10, 9, 15, 13, 4, 12, 11, 2, 4, 10, 14]               105               0.0010
# [15, 3, 8, 13, 5, 2, 9, 7, 15, 0, 7, 9, 8, 8, 2, 13]                   102               0.0010
# [3, 4, 1, 15, 7, 11, 3, 11, 13, 14, 15, 4, 15, 4, 7, 10]               93                0.0009
# [3, 13, 15, 11, 13, 4, 12, 4, 11, 7, 14, 2, 8, 8, 6, 3]                106               0.0011
# [15, 14, 15, 3, 8, 9, 1, 5, 15, 6, 8, 9, 5, 1, 15, 9]                  94                0.0009
# [14, 4, 4, 11, 5, 11, 2, 8, 1, 11, 3, 10, 9, 13, 3, 9]                 105               0.0010
# [5, 0, 1, 13, 9, 7, 5, 1, 9, 4, 5, 5, 4, 5, 4, 6]                      91                0.0009
# [6, 2, 9, 13, 13, 13, 7, 15, 8, 6, 6, 10, 10, 4, 14, 12]               102               0.0010
# [7, 7, 15, 7, 0, 3, 12, 3, 9, 4, 0, 12, 14, 7, 7, 6]                   95                0.0009
# [6, 12, 8, 0, 10, 5, 2, 5, 13, 15, 11, 3, 5, 8, 5, 3]                  99                0.0010
# [14, 15, 15, 14, 10, 12, 7, 7, 6, 10, 4, 14, 12, 5, 3, 3]              98                0.0010
# [0, 3, 13, 7, 2, 11, 6, 11, 6, 8, 15, 10, 7, 1, 7, 8]                  105               0.0010
# [15, 2, 3, 9, 5, 14, 2, 14, 8, 3, 3, 8, 13, 10, 12, 6]                 101               0.0010
# [8, 10, 9, 14, 4, 2, 13, 8, 11, 9, 15, 9, 9, 14, 11, 8]                95                0.0009
# [10, 5, 0, 7, 8, 4, 12, 4, 10, 1, 7, 12, 1, 8, 9, 11]                  102               0.0010
# [5, 15, 14, 9, 3, 15, 9, 8, 1, 5, 6, 9, 9, 11, 12, 13]                 98                0.0010
# [7, 10, 4, 14, 12, 3, 9, 1, 1, 2, 5, 9, 3, 4, 7, 3]                    99                0.0010
# [7, 13, 15, 14, 6, 9, 5, 2, 12, 0, 13, 5, 13, 7, 13, 13]               97                0.0010
# [15, 3, 8, 2, 13, 14, 9, 3, 0, 9, 11, 10, 8, 0, 4, 9]                  103               0.0010
# [9, 12, 3, 4, 14, 10, 7, 11, 9, 10, 15, 9, 4, 15, 9, 6]                96                0.0010
# [15, 15, 7, 4, 10, 2, 6, 10, 8, 14, 2, 14, 3, 11, 11, 5]               101               0.0010
# [9, 0, 15, 5, 1, 14, 1, 11, 12, 10, 3, 13, 13, 7, 12, 7]               108               0.0011
# [7, 6, 8, 11, 7, 5, 14, 14, 8, 14, 15, 12, 6, 4, 0, 14]                97                0.0010
# [7, 11, 10, 2, 1, 15, 1, 14, 10, 7, 8, 4, 7, 13, 11, 13]               98                0.0010
# [3, 3, 9, 0, 10, 5, 3, 6, 2, 11, 0, 7, 11, 15, 11, 12]                 98                0.0010
# [14, 12, 10, 13, 4, 10, 8, 5, 15, 14, 1, 9, 5, 8, 6, 8]                102               0.0010
# [13, 14, 8, 14, 13, 12, 3, 8, 12, 1, 7, 0, 11, 5, 13, 0]               100               0.0010
# [2, 12, 14, 10, 14, 14, 6, 6, 15, 3, 9, 14, 7, 9, 6, 13]               100               0.0010
# [8, 6, 8, 8, 1, 15, 8, 1, 6, 9, 14, 8, 10, 14, 4, 5]                   95                0.0009
# [6, 5, 2, 0, 15, 14, 12, 5, 0, 6, 0, 7, 11, 4, 0, 14]                  102               0.0010
# [5, 2, 14, 5, 11, 8, 14, 9, 2, 6, 1, 3, 12, 7, 1, 6]                   105               0.0010
# [1, 2, 2, 10, 4, 15, 14, 2, 9, 14, 4, 8, 7, 6, 1, 9]                   102               0.0010
# [15, 7, 8, 10, 7, 2, 5, 13, 2, 4, 5, 4, 5, 8, 2, 15]                   94                0.0009
# [1, 9, 11, 8, 9, 12, 9, 3, 0, 13, 15, 7, 0, 4, 5, 12]                  104               0.0010
# [2, 11, 10, 15, 7, 1, 2, 9, 11, 8, 15, 2, 8, 2, 15, 14]                99                0.0010
# [13, 1, 13, 7, 8, 0, 3, 4, 10, 1, 10, 13, 11, 2, 5, 8]                 104               0.0010
# [2, 3, 2, 9, 11, 7, 6, 13, 7, 4, 9, 4, 0, 6, 14, 10]                   94                0.0009
# [8, 6, 1, 12, 4, 15, 1, 3, 8, 6, 8, 13, 11, 5, 6, 2]                   100               0.0010
# [5, 11, 3, 6, 12, 5, 15, 8, 15, 15, 15, 5, 8, 12, 12, 14]              98                0.0010
# [7, 1, 13, 11, 5, 5, 5, 2, 6, 8, 8, 15, 10, 9, 10, 12]                 103               0.0010
# [7, 13, 6, 1, 1, 11, 13, 11, 14, 11, 4, 9, 8, 12, 10, 14]              103               0.0010
# [13, 3, 5, 0, 3, 13, 7, 0, 3, 13, 6, 7, 15, 5, 3, 3]                   93                0.0009
# [7, 8, 11, 12, 2, 10, 1, 0, 15, 6, 2, 8, 7, 9, 10, 14]                 101               0.0010
# [13, 6, 12, 4, 1, 8, 9, 10, 13, 3, 3, 12, 13, 12, 9, 9]                93                0.0009
# [4, 7, 4, 8, 3, 15, 13, 11, 7, 7, 3, 11, 10, 7, 10, 4]                 99                0.0010
# [7, 1, 0, 11, 7, 9, 13, 9, 14, 5, 8, 9, 4, 12, 6, 14]                  100               0.0010
# [5, 5, 7, 7, 2, 6, 4, 4, 15, 4, 12, 8, 6, 8, 6, 14]                    100               0.0010
# [4, 13, 11, 12, 11, 9, 3, 12, 15, 5, 11, 10, 8, 15, 6, 6]              100               0.0010
# [1, 15, 0, 14, 2, 13, 6, 3, 4, 6, 12, 4, 2, 0, 5, 0]                   107               0.0011
# [10, 4, 11, 4, 5, 5, 11, 12, 10, 12, 15, 7, 2, 2, 12, 3]               102               0.0010
# [4, 7, 10, 10, 12, 5, 12, 8, 12, 8, 9, 4, 2, 15, 12, 11]               103               0.0010
# [14, 0, 10, 6, 3, 13, 2, 4, 10, 0, 0, 2, 7, 15, 3, 3]                  103               0.0010
# [2, 7, 8, 4, 2, 6, 13, 12, 9, 14, 11, 5, 9, 5, 5, 13]                  100               0.0010
# [0, 5, 15, 13, 1, 5, 2, 10, 6, 14, 9, 13, 10, 6, 2, 5]                 105               0.0010
# [6, 4, 11, 7, 15, 11, 2, 8, 7, 8, 5, 6, 14, 15, 11, 15]                102               0.0010
# [1, 4, 13, 8, 6, 4, 9, 2, 8, 3, 9, 4, 6, 15, 4, 6]                     98                0.0010
# [15, 3, 6, 10, 12, 1, 5, 7, 14, 0, 12, 12, 6, 0, 6, 15]                106               0.0011
# [0, 7, 15, 8, 0, 4, 11, 8, 2, 3, 5, 11, 2, 4, 6, 11]                   104               0.0010
# [14, 15, 14, 7, 8, 13, 10, 3, 10, 15, 13, 7, 9, 0, 10, 1]              95                0.0009
# [3, 4, 11, 3, 2, 7, 4, 11, 8, 4, 6, 4, 15, 9, 15, 6]                   98                0.0010
# [10, 14, 11, 6, 3, 4, 12, 1, 10, 12, 9, 2, 3, 11, 7, 0]                100               0.0010
# [3, 15, 12, 0, 1, 0, 1, 5, 9, 12, 15, 4, 12, 6, 5, 13]                 102               0.0010
# [0, 0, 1, 6, 2, 5, 10, 11, 1, 7, 3, 4, 14, 7, 15, 15]                  103               0.0010
# [2, 14, 3, 13, 12, 11, 11, 4, 15, 15, 12, 6, 15, 5, 2, 11]             104               0.0010
# [15, 12, 2, 10, 6, 2, 8, 5, 11, 1, 8, 11, 13, 11, 12, 13]              97                0.0010
# [15, 8, 7, 12, 15, 9, 4, 1, 7, 3, 7, 7, 6, 14, 4, 7]                   97                0.0010
# [12, 7, 12, 10, 10, 12, 9, 0, 4, 15, 14, 1, 15, 6, 10, 4]              95                0.0009
# [2, 8, 0, 15, 1, 9, 12, 6, 15, 4, 12, 15, 9, 15, 1, 15]                95                0.0009
# [8, 6, 5, 6, 3, 3, 7, 0, 6, 14, 0, 2, 6, 4, 3, 9]                      95                0.0009
# [1, 8, 10, 6, 3, 10, 7, 10, 1, 6, 14, 8, 13, 15, 2, 5]                 104               0.0010
# [9, 8, 11, 0, 10, 15, 11, 2, 4, 3, 9, 1, 11, 0, 7, 11]                 101               0.0010
# [7, 15, 3, 1, 3, 4, 2, 8, 13, 9, 7, 11, 10, 5, 12, 5]                  105               0.0010
# [10, 12, 4, 5, 5, 15, 13, 10, 11, 4, 12, 13, 7, 15, 1, 10]             92                0.0009
# [5, 0, 11, 1, 5, 10, 6, 0, 7, 12, 9, 10, 1, 12, 1, 13]                 94                0.0009
# [0, 2, 10, 2, 2, 8, 15, 6, 15, 5, 2, 7, 8, 5, 4, 7]                    96                0.0010
# [4, 15, 15, 4, 10, 2, 11, 4, 12, 3, 4, 5, 12, 11, 8, 3]                92                0.0009
# [4, 12, 6, 1, 9, 14, 11, 10, 13, 12, 4, 8, 2, 5, 3, 1]                 99                0.0010
# [7, 4, 2, 10, 13, 0, 10, 10, 2, 15, 0, 2, 15, 12, 12, 2]               95                0.0009
# [6, 4, 2, 15, 5, 5, 3, 15, 7, 7, 6, 14, 14, 3, 5, 9]                   105               0.0010
# [13, 2, 10, 8, 1, 14, 4, 15, 9, 5, 15, 10, 0, 0, 13, 5]                107               0.0011
# [10, 2, 3, 3, 0, 2, 9, 11, 0, 8, 1, 11, 9, 5, 6, 15]                   105               0.0010
# [8, 6, 13, 6, 13, 1, 5, 11, 8, 15, 15, 5, 8, 13, 2, 6]                 103               0.0010
# [0, 13, 8, 9, 3, 1, 2, 3, 13, 0, 6, 11, 9, 12, 14, 5]                  101               0.0010
# [9, 2, 12, 0, 0, 13, 6, 1, 0, 0, 14, 3, 3, 14, 15, 5]                  99                0.0010
# [15, 9, 14, 13, 13, 11, 10, 4, 10, 2, 8, 12, 13, 9, 6, 13]             102               0.0010
# [14, 2, 6, 1, 7, 13, 8, 7, 3, 6, 12, 10, 15, 14, 3, 0]                 104               0.0010
# [0, 12, 11, 10, 15, 7, 7, 3, 9, 1, 10, 12, 0, 10, 7, 10]               94                0.0009
# [3, 6, 0, 11, 0, 15, 13, 13, 15, 7, 14, 9, 10, 4, 9, 6]                102               0.0010
# [5, 9, 1, 10, 6, 13, 10, 5, 10, 1, 1, 4, 0, 1, 2, 3]                   92                0.0009
# [0, 11, 9, 1, 13, 0, 0, 13, 8, 10, 1, 10, 9, 12, 13, 7]                103               0.0010
# [6, 12, 3, 11, 12, 4, 4, 0, 3, 15, 8, 5, 8, 6, 2, 10]                  107               0.0011
# [6, 6, 7, 3, 6, 5, 11, 3, 2, 3, 12, 3, 8, 8, 12, 5]                    93                0.0009
# [9, 9, 15, 0, 7, 8, 14, 2, 11, 13, 4, 6, 14, 3, 0, 4]                  103               0.0010
# [0, 13, 9, 1, 1, 14, 9, 6, 5, 15, 4, 9, 5, 10, 10, 1]                  102               0.0010
# [6, 14, 9, 12, 7, 6, 12, 13, 2, 8, 11, 1, 14, 2, 1, 5]                 101               0.0010
# [10, 9, 5, 15, 0, 12, 6, 2, 0, 4, 15, 11, 3, 14, 2, 11]                111               0.0011
# [7, 7, 5, 5, 3, 4, 1, 5, 5, 1, 4, 3, 7, 5, 6, 0]                       88                0.0009
# [15, 11, 4, 8, 6, 2, 14, 13, 5, 6, 9, 2, 0, 11, 0, 7]                  104               0.0010
# [0, 14, 6, 11, 7, 3, 15, 14, 4, 11, 6, 10, 11, 15, 9, 0]               101               0.0010
# [2, 8, 10, 10, 0, 4, 0, 2, 3, 4, 14, 2, 11, 4, 1, 4]                   97                0.0010
# [5, 7, 7, 3, 12, 7, 1, 15, 2, 4, 11, 0, 11, 1, 4, 1]                   107               0.0011
# [13, 7, 12, 11, 1, 0, 3, 4, 15, 12, 1, 15, 7, 0, 9, 5]                 99                0.0010
# [1, 5, 13, 4, 5, 4, 4, 7, 6, 2, 15, 8, 9, 13, 12, 12]                  98                0.0010
# [13, 1, 10, 7, 14, 10, 11, 15, 14, 6, 0, 5, 14, 14, 6, 4]              104               0.0010
# [6, 0, 4, 9, 1, 7, 14, 0, 5, 10, 10, 3, 13, 8, 7, 12]                  102               0.0010
# [11, 9, 7, 13, 10, 0, 5, 15, 14, 12, 11, 5, 5, 14, 4, 15]              103               0.0010
# [10, 8, 5, 7, 2, 3, 15, 3, 0, 5, 11, 15, 4, 0, 9, 6]                   104               0.0010
# [11, 0, 7, 4, 3, 1, 5, 5, 15, 14, 10, 2, 14, 5, 0, 3]                  102               0.0010
# [2, 2, 14, 3, 1, 11, 12, 4, 4, 7, 8, 9, 1, 9, 4, 4]                    98                0.0010
# [6, 6, 8, 6, 7, 5, 14, 4, 4, 4, 3, 3, 5, 4, 15, 13]                    98                0.0010
# [0, 14, 9, 0, 1, 5, 14, 9, 13, 13, 11, 7, 0, 12, 8, 13]                106               0.0011
# [1, 9, 0, 3, 5, 7, 2, 0, 9, 11, 8, 3, 15, 13, 14, 14]                  108               0.0011
# [9, 1, 15, 11, 7, 7, 7, 3, 14, 5, 9, 0, 15, 11, 1, 15]                 104               0.0010
# [6, 15, 1, 8, 2, 1, 4, 13, 5, 10, 8, 13, 4, 3, 1, 7]                   103               0.0010
# [13, 15, 4, 0, 9, 11, 0, 6, 8, 10, 2, 1, 15, 14, 12, 5]                104               0.0010
# [4, 4, 9, 14, 0, 6, 4, 8, 9, 8, 8, 0, 0, 4, 4, 12]                     88                0.0009
# [3, 11, 2, 13, 8, 1, 9, 10, 0, 14, 12, 10, 2, 15, 8, 12]               107               0.0011
# [13, 13, 0, 0, 8, 1, 9, 0, 11, 5, 1, 12, 10, 8, 0, 2]                  105               0.0010
# [14, 10, 0, 7, 6, 5, 5, 14, 9, 3, 0, 2, 11, 7, 14, 10]                 104               0.0010
# [8, 4, 10, 2, 7, 9, 7, 5, 8, 6, 0, 14, 4, 14, 4, 4]                    99                0.0010
# [8, 15, 9, 13, 14, 13, 1, 3, 0, 1, 9, 14, 9, 6, 4, 15]                 99                0.0010
# [7, 11, 1, 8, 0, 8, 7, 14, 12, 6, 11, 3, 6, 4, 10, 2]                  107               0.0011
# [1, 8, 1, 0, 10, 12, 13, 14, 11, 1, 15, 9, 7, 3, 0, 1]                 97                0.0010
# [7, 11, 7, 13, 11, 2, 9, 3, 10, 4, 13, 10, 9, 14, 6, 6]                103               0.0010
# [0, 4, 9, 2, 8, 2, 11, 12, 14, 7, 7, 12, 13, 10, 11, 8]                98                0.0010
# [10, 1, 9, 2, 8, 0, 11, 7, 12, 13, 15, 3, 14, 12, 1, 1]                104               0.0010
# [8, 6, 14, 7, 7, 12, 7, 6, 7, 9, 6, 4, 7, 9, 13, 4]                    93                0.0009
# [9, 3, 6, 6, 10, 13, 10, 12, 13, 10, 12, 12, 1, 12, 1, 6]              96                0.0010
# [6, 10, 5, 8, 1, 12, 12, 4, 11, 4, 3, 15, 13, 15, 1, 0]                106               0.0011
# [4, 15, 12, 14, 15, 8, 11, 5, 9, 8, 10, 6, 3, 9, 3, 10]                107               0.0011
# [14, 11, 0, 2, 3, 11, 1, 11, 1, 14, 15, 10, 14, 0, 4, 7]               104               0.0010
# [6, 6, 9, 7, 5, 15, 9, 14, 7, 13, 8, 8, 11, 3, 1, 12]                  109               0.0011
# [11, 0, 13, 14, 7, 7, 0, 3, 0, 13, 14, 8, 9, 10, 8, 14]                98                0.0010
# [1, 12, 13, 7, 4, 9, 15, 11, 7, 3, 11, 1, 13, 8, 1, 15]                97                0.0010
# [4, 15, 3, 1, 6, 4, 15, 14, 14, 8, 3, 9, 6, 9, 3, 6]                   99                0.0010
# [2, 14, 7, 2, 13, 2, 15, 7, 3, 0, 9, 7, 11, 10, 4, 14]                 99                0.0010
# [12, 12, 13, 5, 8, 7, 3, 3, 14, 2, 0, 4, 7, 2, 13, 4]                  100               0.0010
# [11, 6, 6, 13, 9, 3, 11, 7, 1, 9, 7, 12, 7, 1, 12, 2]                  100               0.0010
# [15, 8, 1, 1, 7, 0, 2, 11, 1, 2, 10, 9, 13, 7, 9, 8]                   99                0.0010
# [5, 0, 13, 0, 10, 12, 13, 1, 6, 15, 9, 12, 13, 6, 1, 12]               99                0.0010
# [10, 4, 5, 5, 1, 15, 8, 1, 11, 15, 5, 11, 15, 15, 5, 14]               90                0.0009
# [0, 14, 2, 4, 15, 4, 2, 4, 3, 1, 11, 4, 3, 0, 8, 6]                    101               0.0010
# [1, 7, 0, 10, 8, 10, 8, 13, 6, 14, 15, 0, 15, 0, 10, 7]                102               0.0010
# [0, 14, 9, 5, 12, 15, 7, 0, 7, 14, 13, 3, 1, 14, 11, 6]                108               0.0011
# [7, 14, 4, 6, 7, 4, 14, 6, 7, 7, 11, 15, 9, 10, 5, 11]                 97                0.0010
# [3, 15, 3, 13, 5, 8, 11, 2, 7, 1, 8, 11, 15, 4, 7, 9]                  105               0.0010
# [13, 9, 15, 4, 1, 8, 0, 10, 9, 0, 8, 11, 5, 7, 8, 3]                   99                0.0010
# [0, 7, 5, 4, 13, 7, 14, 9, 10, 9, 8, 4, 15, 13, 14, 4]                 98                0.0010
# [9, 4, 0, 8, 5, 5, 8, 1, 0, 15, 9, 7, 5, 12, 7, 4]                     104               0.0010
# [13, 8, 15, 10, 11, 6, 5, 8, 2, 10, 4, 13, 14, 12, 6, 0]               99                0.0010
# [14, 7, 9, 13, 15, 6, 4, 5, 9, 1, 4, 8, 3, 11, 13, 9]                  100               0.0010
# [3, 12, 14, 14, 15, 11, 3, 2, 15, 3, 4, 8, 1, 15, 3, 2]                92                0.0009
# [13, 14, 7, 1, 6, 12, 1, 9, 2, 14, 9, 3, 4, 4, 1, 9]                   99                0.0010
# [12, 7, 2, 9, 4, 13, 11, 1, 14, 14, 14, 2, 1, 9, 2, 11]                96                0.0010
# [12, 13, 4, 14, 4, 12, 13, 2, 11, 4, 9, 10, 4, 8, 1, 6]                98                0.0010
# [15, 3, 12, 8, 0, 4, 2, 13, 1, 7, 13, 0, 15, 14, 13, 2]                102               0.0010
# [10, 15, 12, 1, 2, 8, 11, 15, 10, 8, 5, 10, 13, 8, 3, 5]               103               0.0010
# [6, 10, 6, 14, 4, 3, 12, 4, 4, 10, 3, 5, 0, 5, 13, 15]                 102               0.0010
# [11, 9, 2, 1, 12, 6, 1, 12, 7, 6, 2, 2, 6, 6, 13, 0]                   98                0.0010
# [1, 11, 3, 11, 15, 14, 4, 3, 13, 4, 6, 3, 12, 5, 7, 3]                 99                0.0010
# [3, 5, 15, 14, 4, 4, 15, 10, 9, 5, 1, 15, 7, 1, 12, 12]                103               0.0010
# [13, 13, 2, 9, 4, 13, 7, 2, 12, 2, 5, 13, 5, 11, 11, 5]                98                0.0010
# [2, 4, 7, 2, 4, 5, 6, 3, 9, 7, 3, 12, 8, 8, 2, 13]                     101               0.0010
# [6, 12, 1, 8, 11, 7, 2, 7, 9, 7, 12, 10, 13, 7, 5, 10]                 107               0.0011
# [5, 1, 8, 8, 4, 10, 2, 12, 15, 13, 11, 12, 1, 2, 9, 13]                99                0.0010
# [11, 6, 2, 8, 13, 15, 6, 9, 8, 5, 14, 13, 10, 4, 14, 1]                99                0.0010
# [6, 13, 7, 2, 7, 9, 14, 0, 4, 2, 13, 0, 11, 11, 9, 6]                  102               0.0010
# [2, 2, 10, 14, 9, 12, 4, 3, 12, 11, 14, 8, 1, 10, 4, 5]                102               0.0010
# [3, 13, 2, 1, 2, 0, 5, 2, 5, 8, 7, 14, 7, 12, 1, 5]                    97                0.0010
# [0, 2, 6, 10, 1, 14, 4, 3, 14, 7, 12, 10, 11, 5, 14, 2]                108               0.0011
# [2, 11, 2, 14, 7, 1, 7, 13, 9, 2, 10, 8, 3, 15, 12, 4]                 105               0.0010
# [14, 9, 13, 9, 3, 8, 3, 0, 6, 6, 10, 4, 14, 0, 12, 0]                  98                0.0010
# [3, 8, 15, 13, 10, 3, 14, 3, 8, 0, 4, 15, 8, 13, 10, 2]                95                0.0009
# [13, 11, 9, 7, 5, 2, 1, 7, 7, 5, 11, 8, 6, 7, 0, 7]                    100               0.0010
# [0, 1, 13, 13, 2, 11, 4, 11, 6, 1, 14, 15, 14, 1, 15, 2]               97                0.0010
# [6, 14, 12, 7, 15, 13, 10, 7, 12, 1, 0, 14, 5, 11, 2, 2]               104               0.0010
# [4, 10, 13, 14, 1, 11, 12, 7, 1, 15, 10, 8, 13, 3, 3, 5]               103               0.0010
# [12, 10, 10, 8, 6, 4, 10, 1, 8, 3, 10, 4, 3, 8, 8, 4]                  91                0.0009
# [7, 12, 9, 12, 7, 9, 11, 12, 12, 3, 10, 0, 11, 12, 3, 0]               91                0.0009
# [10, 2, 0, 5, 8, 10, 10, 3, 2, 10, 10, 13, 6, 6, 4, 1]                 95                0.0009
# [11, 2, 3, 8, 13, 13, 12, 12, 0, 12, 1, 11, 14, 14, 12, 12]            94                0.0009
# [3, 4, 6, 12, 7, 5, 13, 1, 7, 11, 0, 3, 12, 6, 7, 12]                  99                0.0010
# [1, 1, 5, 15, 14, 11, 6, 0, 14, 2, 10, 11, 15, 7, 6, 0]                96                0.0010
# [10, 4, 0, 14, 0, 14, 0, 1, 3, 5, 12, 2, 4, 12, 2, 4]                  105               0.0010
# [3, 0, 10, 15, 2, 14, 7, 9, 15, 6, 6, 4, 6, 15, 3, 11]                 105               0.0010
# ...
# LOOP: 3523 / 10000 --> Max fitness: 114
# LOOP: 3524 / 10000 --> Max fitness: 116
# LOOP: 3525 / 10000 --> Max fitness: 114
# LOOP: 3526 / 10000 --> Max fitness: 116
# LOOP: 3527 / 10000 --> Max fitness: 115
# LOOP: 3528 / 10000 --> Max fitness: 117
# LOOP: 3529 / 10000 --> Max fitness: 117
# LOOP: 3530 / 10000 --> Max fitness: 116
# LOOP: 3531 / 10000 --> Max fitness: 114
# LOOP: 3532 / 10000 --> Max fitness: 116
# LOOP: 3533 / 10000 --> Max fitness: 115
# LOOP: 3534 / 10000 --> Max fitness: 115
# LOOP: 3535 / 10000 --> Max fitness: 117
# LOOP: 3536 / 10000 --> Max fitness: 117
# LOOP: 3537 / 10000 --> Max fitness: 116
# LOOP: 3538 / 10000 --> Max fitness: 115
# LOOP: 3539 / 10000 --> Max fitness: 115
# LOOP: 3540 / 10000 --> Max fitness: 116
# LOOP: 3541 / 10000 --> Max fitness: 117
# LOOP: 3542 / 10000 --> Max fitness: 115
# LOOP: 3543 / 10000 --> Max fitness: 116
# LOOP: 3544 / 10000 --> Max fitness: 116
# LOOP: 3545 / 10000 --> Max fitness: 117
# LOOP: 3546 / 10000 --> Max fitness: 114
# LOOP: 3547 / 10000 --> Max fitness: 115
# LOOP: 3548 / 10000 --> Max fitness: 115
# LOOP: 3549 / 10000 --> Max fitness: 116
# LOOP: 3550 / 10000 --> Max fitness: 115
# LOOP: 3551 / 10000 --> Max fitness: 114
# LOOP: 3552 / 10000 --> Max fitness: 115
# LOOP: 3553 / 10000 --> Max fitness: 115
# LOOP: 3554 / 10000 --> Max fitness: 114
# LOOP: 3555 / 10000 --> Max fitness: 116
# LOOP: 3556 / 10000 --> Max fitness: 115
# LOOP: 3557 / 10000 --> Max fitness: 115
# LOOP: 3558 / 10000 --> Max fitness: 116
# LOOP: 3559 / 10000 --> Max fitness: 117
# LOOP: 3560 / 10000 --> Max fitness: 115
# LOOP: 3561 / 10000 --> Max fitness: 115
# LOOP: 3562 / 10000 --> Max fitness: 116
# LOOP: 3563 / 10000 --> Max fitness: 115
# LOOP: 3564 / 10000 --> Max fitness: 116
# LOOP: 3565 / 10000 --> Max fitness: 115
# LOOP: 3566 / 10000 --> Max fitness: 114
# LOOP: 3567 / 10000 --> Max fitness: 114
# LOOP: 3568 / 10000 --> Max fitness: 116
# LOOP: 3569 / 10000 --> Max fitness: 115
# LOOP: 3570 / 10000 --> Max fitness: 116
# LOOP: 3571 / 10000 --> Max fitness: 115
# LOOP: 3572 / 10000 --> Max fitness: 115
# LOOP: 3573 / 10000 --> Max fitness: 115
# LOOP: 3574 / 10000 --> Max fitness: 115
# LOOP: 3575 / 10000 --> Max fitness: 114
# LOOP: 3576 / 10000 --> Max fitness: 115
# LOOP: 3577 / 10000 --> Max fitness: 115
# LOOP: 3578 / 10000 --> Max fitness: 116
# LOOP: 3579 / 10000 --> Max fitness: 115
# LOOP: 3580 / 10000 --> Max fitness: 115
# LOOP: 3581 / 10000 --> Max fitness: 116
# LOOP: 3582 / 10000 --> Max fitness: 115
# LOOP: 3583 / 10000 --> Max fitness: 114
# LOOP: 3584 / 10000 --> Max fitness: 115
# LOOP: 3585 / 10000 --> Max fitness: 116
# LOOP: 3586 / 10000 --> Max fitness: 115
# LOOP: 3587 / 10000 --> Max fitness: 115
# LOOP: 3588 / 10000 --> Max fitness: 117
# LOOP: 3589 / 10000 --> Max fitness: 116
# LOOP: 3590 / 10000 --> Max fitness: 115
# LOOP: 3591 / 10000 --> Max fitness: 118
# LOOP: 3592 / 10000 --> Max fitness: 116
# LOOP: 3593 / 10000 --> Max fitness: 115
# LOOP: 3594 / 10000 --> Max fitness: 116
# LOOP: 3595 / 10000 --> Max fitness: 116
# LOOP: 3596 / 10000 --> Max fitness: 115
# LOOP: 3597 / 10000 --> Max fitness: 115
# LOOP: 3598 / 10000 --> Max fitness: 116
# LOOP: 3599 / 10000 --> Max fitness: 114
# LOOP: 3600 / 10000 --> Max fitness: 116
# LOOP: 3601 / 10000 --> Max fitness: 116
# LOOP: 3602 / 10000 --> Max fitness: 115
# LOOP: 3603 / 10000 --> Max fitness: 116
# LOOP: 3604 / 10000 --> Max fitness: 116
# LOOP: 3605 / 10000 --> Max fitness: 116
# LOOP: 3606 / 10000 --> Max fitness: 116
# LOOP: 3607 / 10000 --> Max fitness: 115
# LOOP: 3608 / 10000 --> Max fitness: 115
# LOOP: 3609 / 10000 --> Max fitness: 115
# LOOP: 3610 / 10000 --> Max fitness: 115
# LOOP: 3611 / 10000 --> Max fitness: 116
# LOOP: 3612 / 10000 --> Max fitness: 115
# LOOP: 3613 / 10000 --> Max fitness: 115
# LOOP: 3614 / 10000 --> Max fitness: 116
# LOOP: 3615 / 10000 --> Max fitness: 115
# LOOP: 3616 / 10000 --> Max fitness: 115
# LOOP: 3617 / 10000 --> Max fitness: 115
# LOOP: 3618 / 10000 --> Max fitness: 115
# LOOP: 3619 / 10000 --> Max fitness: 116
# LOOP: 3620 / 10000 --> Max fitness: 115
# LOOP: 3621 / 10000 --> Max fitness: 115
# LOOP: 3622 / 10000 --> Max fitness: 114
# LOOP: 3623 / 10000 --> Max fitness: 116
# LOOP: 3624 / 10000 --> Max fitness: 117
# LOOP: 3625 / 10000 --> Max fitness: 115
# LOOP: 3626 / 10000 --> Max fitness: 115
# LOOP: 3627 / 10000 --> Max fitness: 115
# LOOP: 3628 / 10000 --> Max fitness: 116
# LOOP: 3629 / 10000 --> Max fitness: 116
# LOOP: 3630 / 10000 --> Max fitness: 115
# LOOP: 3631 / 10000 --> Max fitness: 116
# LOOP: 3632 / 10000 --> Max fitness: 116
# LOOP: 3633 / 10000 --> Max fitness: 116
# LOOP: 3634 / 10000 --> Max fitness: 116
# LOOP: 3635 / 10000 --> Max fitness: 115
# LOOP: 3636 / 10000 --> Max fitness: 115
# LOOP: 3637 / 10000 --> Max fitness: 115
# LOOP: 3638 / 10000 --> Max fitness: 116
# LOOP: 3639 / 10000 --> Max fitness: 117
# LOOP: 3640 / 10000 --> Max fitness: 115
# LOOP: 3641 / 10000 --> Max fitness: 116
# LOOP: 3642 / 10000 --> Max fitness: 114
# LOOP: 3643 / 10000 --> Max fitness: 115
# LOOP: 3644 / 10000 --> Max fitness: 115
# LOOP: 3645 / 10000 --> Max fitness: 116
# LOOP: 3646 / 10000 --> Max fitness: 116
# LOOP: 3647 / 10000 --> Max fitness: 116
# LOOP: 3648 / 10000 --> Max fitness: 116
# LOOP: 3649 / 10000 --> Max fitness: 116
# LOOP: 3650 / 10000 --> Max fitness: 115
# LOOP: 3651 / 10000 --> Max fitness: 115
# LOOP: 3652 / 10000 --> Max fitness: 114
# LOOP: 3653 / 10000 --> Max fitness: 115
# LOOP: 3654 / 10000 --> Max fitness: 114
# LOOP: 3655 / 10000 --> Max fitness: 116
# LOOP: 3656 / 10000 --> Max fitness: 117
# LOOP: 3657 / 10000 --> Max fitness: 115
# LOOP: 3658 / 10000 --> Max fitness: 114
# LOOP: 3659 / 10000 --> Max fitness: 115
# LOOP: 3660 / 10000 --> Max fitness: 116
# LOOP: 3661 / 10000 --> Max fitness: 114
# LOOP: 3662 / 10000 --> Max fitness: 116
# LOOP: 3663 / 10000 --> Max fitness: 115
# LOOP: 3664 / 10000 --> Max fitness: 115
# LOOP: 3665 / 10000 --> Max fitness: 115
# LOOP: 3666 / 10000 --> Max fitness: 115
# LOOP: 3667 / 10000 --> Max fitness: 117
# LOOP: 3668 / 10000 --> Max fitness: 116
# LOOP: 3669 / 10000 --> Max fitness: 117
# LOOP: 3670 / 10000 --> Max fitness: 116
# LOOP: 3671 / 10000 --> Max fitness: 116
# LOOP: 3672 / 10000 --> Max fitness: 114
# LOOP: 3673 / 10000 --> Max fitness: 115
# LOOP: 3674 / 10000 --> Max fitness: 115
# LOOP: 3675 / 10000 --> Max fitness: 115
# LOOP: 3676 / 10000 --> Max fitness: 117
# LOOP: 3677 / 10000 --> Max fitness: 115
# LOOP: 3678 / 10000 --> Max fitness: 116
# LOOP: 3679 / 10000 --> Max fitness: 116
# LOOP: 3680 / 10000 --> Max fitness: 115
# LOOP: 3681 / 10000 --> Max fitness: 116
# LOOP: 3682 / 10000 --> Max fitness: 116
# LOOP: 3683 / 10000 --> Max fitness: 116
# LOOP: 3684 / 10000 --> Max fitness: 116
# LOOP: 3685 / 10000 --> Max fitness: 116
# LOOP: 3686 / 10000 --> Max fitness: 116
# LOOP: 3687 / 10000 --> Max fitness: 116
# LOOP: 3688 / 10000 --> Max fitness: 117
# LOOP: 3689 / 10000 --> Max fitness: 116
# LOOP: 3690 / 10000 --> Max fitness: 116
# LOOP: 3691 / 10000 --> Max fitness: 115
# LOOP: 3692 / 10000 --> Max fitness: 114
# LOOP: 3693 / 10000 --> Max fitness: 116
# LOOP: 3694 / 10000 --> Max fitness: 115
# LOOP: 3695 / 10000 --> Max fitness: 115
# LOOP: 3696 / 10000 --> Max fitness: 114
# LOOP: 3697 / 10000 --> Max fitness: 116
# LOOP: 3698 / 10000 --> Max fitness: 115
# LOOP: 3699 / 10000 --> Max fitness: 115
# LOOP: 3700 / 10000 --> Max fitness: 115
# LOOP: 3701 / 10000 --> Max fitness: 116
# LOOP: 3702 / 10000 --> Max fitness: 116
# LOOP: 3703 / 10000 --> Max fitness: 115
# LOOP: 3704 / 10000 --> Max fitness: 116
# LOOP: 3705 / 10000 --> Max fitness: 116
# LOOP: 3706 / 10000 --> Max fitness: 116
# LOOP: 3707 / 10000 --> Max fitness: 115
# LOOP: 3708 / 10000 --> Max fitness: 116
# LOOP: 3709 / 10000 --> Max fitness: 115
# LOOP: 3710 / 10000 --> Max fitness: 115
# LOOP: 3711 / 10000 --> Max fitness: 115
# LOOP: 3712 / 10000 --> Max fitness: 115
# LOOP: 3713 / 10000 --> Max fitness: 115
# LOOP: 3714 / 10000 --> Max fitness: 116
# LOOP: 3715 / 10000 --> Max fitness: 115
# LOOP: 3716 / 10000 --> Max fitness: 116
# LOOP: 3717 / 10000 --> Max fitness: 117
# LOOP: 3718 / 10000 --> Max fitness: 116
# LOOP: 3719 / 10000 --> Max fitness: 114
# LOOP: 3720 / 10000 --> Max fitness: 115
# LOOP: 3721 / 10000 --> Max fitness: 116
# LOOP: 3722 / 10000 --> Max fitness: 115
# LOOP: 3723 / 10000 --> Max fitness: 115
# LOOP: 3724 / 10000 --> Max fitness: 116
# LOOP: 3725 / 10000 --> Max fitness: 116
# LOOP: 3726 / 10000 --> Max fitness: 116
# LOOP: 3727 / 10000 --> Max fitness: 115
# LOOP: 3728 / 10000 --> Max fitness: 115
# LOOP: 3729 / 10000 --> Max fitness: 114
# LOOP: 3730 / 10000 --> Max fitness: 115
# LOOP: 3731 / 10000 --> Max fitness: 117
# LOOP: 3732 / 10000 --> Max fitness: 115
# LOOP: 3733 / 10000 --> Max fitness: 115
# LOOP: 3734 / 10000 --> Max fitness: 115
# LOOP: 3735 / 10000 --> Max fitness: 115
# LOOP: 3736 / 10000 --> Max fitness: 116
# LOOP: 3737 / 10000 --> Max fitness: 116
# LOOP: 3738 / 10000 --> Max fitness: 116
# LOOP: 3739 / 10000 --> Max fitness: 114
# LOOP: 3740 / 10000 --> Max fitness: 115
# LOOP: 3741 / 10000 --> Max fitness: 114
# LOOP: 3742 / 10000 --> Max fitness: 115
# LOOP: 3743 / 10000 --> Max fitness: 116
# LOOP: 3744 / 10000 --> Max fitness: 115
# LOOP: 3745 / 10000 --> Max fitness: 117
# LOOP: 3746 / 10000 --> Max fitness: 115
# LOOP: 3747 / 10000 --> Max fitness: 115
# LOOP: 3748 / 10000 --> Max fitness: 116
# LOOP: 3749 / 10000 --> Max fitness: 117
# LOOP: 3750 / 10000 --> Max fitness: 115
# LOOP: 3751 / 10000 --> Max fitness: 115
# LOOP: 3752 / 10000 --> Max fitness: 115
# LOOP: 3753 / 10000 --> Max fitness: 115
# LOOP: 3754 / 10000 --> Max fitness: 114
# LOOP: 3755 / 10000 --> Max fitness: 114
# LOOP: 3756 / 10000 --> Max fitness: 114
# LOOP: 3757 / 10000 --> Max fitness: 115
# LOOP: 3758 / 10000 --> Max fitness: 115
# LOOP: 3759 / 10000 --> Max fitness: 114
# LOOP: 3760 / 10000 --> Max fitness: 117
# LOOP: 3761 / 10000 --> Max fitness: 115
# LOOP: 3762 / 10000 --> Max fitness: 116
# LOOP: 3763 / 10000 --> Max fitness: 116
# LOOP: 3764 / 10000 --> Max fitness: 115
# LOOP: 3765 / 10000 --> Max fitness: 115
# LOOP: 3766 / 10000 --> Max fitness: 115
# LOOP: 3767 / 10000 --> Max fitness: 114
# LOOP: 3768 / 10000 --> Max fitness: 115
# LOOP: 3769 / 10000 --> Max fitness: 115
# LOOP: 3770 / 10000 --> Max fitness: 116
# LOOP: 3771 / 10000 --> Max fitness: 116
# LOOP: 3772 / 10000 --> Max fitness: 117
# LOOP: 3773 / 10000 --> Max fitness: 115
# LOOP: 3774 / 10000 --> Max fitness: 115
# LOOP: 3775 / 10000 --> Max fitness: 117
# LOOP: 3776 / 10000 --> Max fitness: 115
# LOOP: 3777 / 10000 --> Max fitness: 115
# LOOP: 3778 / 10000 --> Max fitness: 115
# LOOP: 3779 / 10000 --> Max fitness: 116
# LOOP: 3780 / 10000 --> Max fitness: 116
# LOOP: 3781 / 10000 --> Max fitness: 116
# LOOP: 3782 / 10000 --> Max fitness: 114
# LOOP: 3783 / 10000 --> Max fitness: 116
# LOOP: 3784 / 10000 --> Max fitness: 116
# LOOP: 3785 / 10000 --> Max fitness: 115
# LOOP: 3786 / 10000 --> Max fitness: 116
# LOOP: 3787 / 10000 --> Max fitness: 116
# LOOP: 3788 / 10000 --> Max fitness: 116
# LOOP: 3789 / 10000 --> Max fitness: 117
# LOOP: 3790 / 10000 --> Max fitness: 115
# LOOP: 3791 / 10000 --> Max fitness: 116
# LOOP: 3792 / 10000 --> Max fitness: 116
# LOOP: 3793 / 10000 --> Max fitness: 115
# LOOP: 3794 / 10000 --> Max fitness: 115
# LOOP: 3795 / 10000 --> Max fitness: 115
# LOOP: 3796 / 10000 --> Max fitness: 115
# LOOP: 3797 / 10000 --> Max fitness: 118
# LOOP: 3798 / 10000 --> Max fitness: 118
# LOOP: 3799 / 10000 --> Max fitness: 114
# LOOP: 3800 / 10000 --> Max fitness: 115
# LOOP: 3801 / 10000 --> Max fitness: 115
# LOOP: 3802 / 10000 --> Max fitness: 117
# LOOP: 3803 / 10000 --> Max fitness: 114
# LOOP: 3804 / 10000 --> Max fitness: 116
# LOOP: 3805 / 10000 --> Max fitness: 115
# LOOP: 3806 / 10000 --> Max fitness: 115
# LOOP: 3807 / 10000 --> Max fitness: 116
# LOOP: 3808 / 10000 --> Max fitness: 116
# LOOP: 3809 / 10000 --> Max fitness: 117
# LOOP: 3810 / 10000 --> Max fitness: 114
# LOOP: 3811 / 10000 --> Max fitness: 114
# LOOP: 3812 / 10000 --> Max fitness: 114
# LOOP: 3813 / 10000 --> Max fitness: 118
# LOOP: 3814 / 10000 --> Max fitness: 116
# LOOP: 3815 / 10000 --> Max fitness: 117
# LOOP: 3816 / 10000 --> Max fitness: 115
# LOOP: 3817 / 10000 --> Max fitness: 116
# LOOP: 3818 / 10000 --> Max fitness: 116
# LOOP: 3819 / 10000 --> Max fitness: 117
# LOOP: 3820 / 10000 --> Max fitness: 115
# LOOP: 3821 / 10000 --> Max fitness: 114
# LOOP: 3822 / 10000 --> Max fitness: 115
# LOOP: 3823 / 10000 --> Max fitness: 116
# LOOP: 3824 / 10000 --> Max fitness: 115
# LOOP: 3825 / 10000 --> Max fitness: 115
# LOOP: 3826 / 10000 --> Max fitness: 116
# LOOP: 3827 / 10000 --> Max fitness: 115
# LOOP: 3828 / 10000 --> Max fitness: 114
# LOOP: 3829 / 10000 --> Max fitness: 116
# LOOP: 3830 / 10000 --> Max fitness: 115
# LOOP: 3831 / 10000 --> Max fitness: 115
# LOOP: 3832 / 10000 --> Max fitness: 115
# LOOP: 3833 / 10000 --> Max fitness: 115
# LOOP: 3834 / 10000 --> Max fitness: 114
# LOOP: 3835 / 10000 --> Max fitness: 114
# LOOP: 3836 / 10000 --> Max fitness: 114
# LOOP: 3837 / 10000 --> Max fitness: 117
# LOOP: 3838 / 10000 --> Max fitness: 115
# LOOP: 3839 / 10000 --> Max fitness: 114
# LOOP: 3840 / 10000 --> Max fitness: 116
# LOOP: 3841 / 10000 --> Max fitness: 115
# LOOP: 3842 / 10000 --> Max fitness: 115
# LOOP: 3843 / 10000 --> Max fitness: 116
# LOOP: 3844 / 10000 --> Max fitness: 116
# LOOP: 3845 / 10000 --> Max fitness: 115
# LOOP: 3846 / 10000 --> Max fitness: 114
# LOOP: 3847 / 10000 --> Max fitness: 115
# LOOP: 3848 / 10000 --> Max fitness: 115
# LOOP: 3849 / 10000 --> Max fitness: 116
# LOOP: 3850 / 10000 --> Max fitness: 116
# LOOP: 3851 / 10000 --> Max fitness: 114
# LOOP: 3852 / 10000 --> Max fitness: 115
# LOOP: 3853 / 10000 --> Max fitness: 116
# LOOP: 3854 / 10000 --> Max fitness: 115
# LOOP: 3855 / 10000 --> Max fitness: 116
# LOOP: 3856 / 10000 --> Max fitness: 115
# LOOP: 3857 / 10000 --> Max fitness: 115
# LOOP: 3858 / 10000 --> Max fitness: 116
# LOOP: 3859 / 10000 --> Max fitness: 115
# LOOP: 3860 / 10000 --> Max fitness: 115
# LOOP: 3861 / 10000 --> Max fitness: 115
# LOOP: 3862 / 10000 --> Max fitness: 117
# LOOP: 3863 / 10000 --> Max fitness: 117
# LOOP: 3864 / 10000 --> Max fitness: 116
# LOOP: 3865 / 10000 --> Max fitness: 114
# LOOP: 3866 / 10000 --> Max fitness: 116
# LOOP: 3867 / 10000 --> Max fitness: 115
# LOOP: 3868 / 10000 --> Max fitness: 116
# LOOP: 3869 / 10000 --> Max fitness: 117
# LOOP: 3870 / 10000 --> Max fitness: 116
# LOOP: 3871 / 10000 --> Max fitness: 115
# LOOP: 3872 / 10000 --> Max fitness: 114
# LOOP: 3873 / 10000 --> Max fitness: 115
# LOOP: 3874 / 10000 --> Max fitness: 115
# LOOP: 3875 / 10000 --> Max fitness: 115
# LOOP: 3876 / 10000 --> Max fitness: 115
# LOOP: 3877 / 10000 --> Max fitness: 116
# LOOP: 3878 / 10000 --> Max fitness: 115
# LOOP: 3879 / 10000 --> Max fitness: 116
# LOOP: 3880 / 10000 --> Max fitness: 115
# LOOP: 3881 / 10000 --> Max fitness: 114
# LOOP: 3882 / 10000 --> Max fitness: 114
# LOOP: 3883 / 10000 --> Max fitness: 118
# LOOP: 3884 / 10000 --> Max fitness: 115
# LOOP: 3885 / 10000 --> Max fitness: 117
# LOOP: 3886 / 10000 --> Max fitness: 116
# LOOP: 3887 / 10000 --> Max fitness: 117
# LOOP: 3888 / 10000 --> Max fitness: 117
# LOOP: 3889 / 10000 --> Max fitness: 114
# LOOP: 3890 / 10000 --> Max fitness: 114
# LOOP: 3891 / 10000 --> Max fitness: 115
# LOOP: 3892 / 10000 --> Max fitness: 116
# LOOP: 3893 / 10000 --> Max fitness: 116
# LOOP: 3894 / 10000 --> Max fitness: 115
# LOOP: 3895 / 10000 --> Max fitness: 116
# LOOP: 3896 / 10000 --> Max fitness: 115
# LOOP: 3897 / 10000 --> Max fitness: 115
# LOOP: 3898 / 10000 --> Max fitness: 115
# LOOP: 3899 / 10000 --> Max fitness: 115
# LOOP: 3900 / 10000 --> Max fitness: 116
# LOOP: 3901 / 10000 --> Max fitness: 116
# LOOP: 3902 / 10000 --> Max fitness: 116
# LOOP: 3903 / 10000 --> Max fitness: 115
# LOOP: 3904 / 10000 --> Max fitness: 115
# LOOP: 3905 / 10000 --> Max fitness: 114
# LOOP: 3906 / 10000 --> Max fitness: 114
# LOOP: 3907 / 10000 --> Max fitness: 116
# LOOP: 3908 / 10000 --> Max fitness: 116
# LOOP: 3909 / 10000 --> Max fitness: 117
# LOOP: 3910 / 10000 --> Max fitness: 115
# LOOP: 3911 / 10000 --> Max fitness: 115
# LOOP: 3912 / 10000 --> Max fitness: 120
#
# 🟢🟢🟢 SOLUTION FOUND at loop 3912 / 10000
#
#
# State                                                             Length          Fitness Score
# ====================================================================================================
# [14, 3, 8, 2, 9, 13, 1, 4, 15, 10, 6, 11, 5, 7, 12, 0]              16                 120
# Time taken to find the solution: 49.51 seconds
